# %%
import json
import codecs

data = open('test.json').read()
theJSON = json.loads(data)

print(theJSON)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-f31feaad1e78> in <module>()
#       3
#       4 data = open('test.json').read()
# ----> 5 decoded = data.decode('utf-8')
#       6 theJSON = json.loads(decoded)
#       7
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
import json
import codecs

data = open('test.json').read()
theJSON = json.loads(data)

print(theJSON)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-82f2c3a115df> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 theJSON = json.loads(data)
#       6
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

data = open('test.json').read()
theJSON = json.loads(data)

print(theJSON)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-82f2c3a115df> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 theJSON = json.loads(data)
#       6
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-82f2c3a115df> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 theJSON = json.loads(data)
#       6
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

data = open('test.json').read()
x = "היי"
decoded = x.decode('UTF-8')


print(decoded)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-7458c910a8f4> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 decoded = data.decode('UTF-8')
#       6
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

data = open('test.json').read()
x = "היי"
x = x.decode('UTF-8')


print(x)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-991c652c0d3c> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 x = "היי"
#       6 decoded = x.decode('UTF-8')
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

data = open('test.json').read()
x = "היי"
x = x.decode('UTF-8')


print(x)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-33228110fb1f> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 x = "היי"
#       6 x = x.decode('UTF-8')
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

data = open('test.json').read()
x = "היי"
x = x.decode('UTF-8')

x
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-1e62a53ce72e> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5 x = "היי"
#       6 x = x.decode('UTF-8')
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

x = "היי"


x
# Out:
# 'היי'

# %%
import json
import codecs

data = open('test.json').read()


print(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-12-afbfde857d2d> in <module>()
#       2 import codecs
#       3
# ----> 4 data = open('test.json').read()
#       5
#       6
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x90 in position 99: character maps to <undefined>

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()


print(data)
# Out:
# [
#     {
#   		"year": "1980",
#   		"position": [
#            { "1": [{
#         				"songName" : "sss",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#   			          }]
#            },
#            { "2": [{
#         				"songName" : "kuke song",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#         			     }]
#            }
#   		]
#     }
# ]

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()


print(data)
# Out:
# [
#     {
#   		"year": "1980",
#   		"position": [
#            { "1": [{
#         				"songName" : "sss",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#   			          }]
#            },
#            { "2": [{
#         				"songName" : "kuke song",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#         			     }]
#            }
#   		]
#     }
# ]

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()


print(data)
# Out:
# [
#     {
#   		"year": "1980",
#   		"position": [
#            { "1": [{
#         				"songName" : "דדד",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#   			          }]
#            },
#            { "2": [{
#         				"songName" : "kuke song",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#         			     }]
#            }
#   		]
#     }
# ]

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

print(theJSON)
# Out:
# [
#     {
#   		"year": "1980",
#   		"position": [
#            { "1": [{
#         				"songName" : "דדד גגגגג",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#   			          }]
#            },
#            { "2": [{
#         				"songName" : "kuke song",
#         				"lyrics": "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"
#         			     }]
#            }
#   		]
#     }
# ]

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

    for element in theJSON: 
        print (element['year'])
# Out:
# [{'year': '1980', 'position': [{'1': [{'songName': 'דדד גגגגג', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}, {'2': [{'songName': 'kuke song', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}]}]

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

    for element in theJSON: 
        print (element['year'])
# Out:
#   File "<ipython-input-18-3a4e00a7889f>", line 7
#     for element in theJSON:
#     ^
# IndentationError: unexpected indent

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    print (element['songName'])
# Out:
# 1980

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    print (element['songName'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-e09b3bfff882> in <module>()
#       6
#       7 for element in theJSON:
# ----> 8     print (element['songName'])
#       9
#      10
#
# KeyError: 'songName'

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    print (element)
# Out:
# {'year': '1980', 'position': [{'1': [{'songName': 'דדד גגגגג', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}, {'2': [{'songName': 'kuke song', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}]}

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    print (element)
# Out:
# {'year': '1980', 'position': [{'1': [{'songName': 'אני חושב שאת', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}, {'2': [{'songName': 'kuke song', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}]}
# {'year': '1981', 'position': [{'1': [{'songName': 'אני אוהב אותך', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}, {'2': [{'songName': 'kuke song', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}]}]}

# %%
import json
import codecs

data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
     print (element['songName'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-daabf7ecfa17> in <module>()
#       6
#       7 for element in theJSON:
# ----> 8      print (element['songName'])
#
# KeyError: 'songName'

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    for element in element['position']:
     print (element)
# Out:
# 1980
# 1981

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    for element in element['position']:
     print (element + "new line")
# Out:
# {'songName': 'אני חושב שאת', 'position': '1', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'kuke song', 'position': '2', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'אני חושב שאת', 'position': '1', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'kuke song', 'position': '2', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)

for element in theJSON: 
    for element in element['position']:
     print (element + "new line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-afdbddab4b91> in <module>()
#       7 for element in theJSON:
#       8     for element in element['position']:
# ----> 9      print (element + "new line")
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'str'

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     print (element + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-46bee092df75> in <module>()
#       8 for element in theJSON:
#       9     for element in element['position']:
# ---> 10      print (element + 1)
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'int'

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     print (element)
# Out:
# {'songName': 'אני חושב שאת', 'position': '1', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'kuke song', 'position': '2', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'אני חושב שאת', 'position': '1', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'kuke song', 'position': '2', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     del element['lyrics']
    
print(theJSON)
# Out:
# {'songName': 'אני חושב שאת', 'position': '1', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'kuke song', 'position': '2', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'אני חושב שאת', 'position': '3', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}
# {'songName': 'kuke song', 'position': '4', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823'}

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     del element['lyrics']
    
print(theJSON)


with open('data.txt', 'w') as outfile:
    json.dump(theJSON, outfile)
# Out:
# [{'year': '1980', 'position': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}]}, {'year': '1981', 'position': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}]}]

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     del element['lyrics']
    
print(theJSON)


with open('data.json', 'w') as outfile:
    json.dump(theJSON, outfile)
# Out:
# [{'year': '1980', 'position': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}]}, {'year': '1981', 'position': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}]}]

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     del element['lyrics']
    
print(theJSON)


with open('data.json', 'w') as outfile:
    json.dump(theJSON, outfile , ensure_ascii=False)
# Out:
# [{'year': '1980', 'position': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}]}, {'year': '1981', 'position': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}]}]

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['position']:
     del element['lyrics']
    
print(theJSON)

with open("data.json","w", encoding='utf-8') as jsonfile:
        json.dump(theJSON,jsonfile,ensure_ascii=False)
# Out:
# [{'year': '1980', 'position': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}]}, {'year': '1981', 'position': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}]}]
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-33-9c28f67af05f> in <module>()
#      14
#      15 with open('data.json', 'w') as outfile:
# ---> 16     json.dump(theJSON, outfile , ensure_ascii=False)
#
# C:\Users\Niv\Anaconda3\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # a debuggability cost
#     178     for chunk in iterable:
# --> 179         fp.write(chunk)
#     180
#     181
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 1-3: character maps to <undefined>

# %%
import json


data = open('test.json',encoding="utf8").read()
theJSON = json.loads(data)
x = 1

for element in theJSON: 
    for element in element['songs']:
     del element['lyrics']
    
print(theJSON)

with open("data1.json","w", encoding='utf-8') as jsonfile:
        json.dump(theJSON,jsonfile,ensure_ascii=False)
# Out:
# [{'year': '1980', 'position': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}]}, {'year': '1981', 'position': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}]}]

# %%
import json

def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            
data1()
# Out:
# [{'songs': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}], 'year': '1980'}, {'songs': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}], 'year': '1981'}]

# %%
import json

def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            
data1()
# Out:
# [{'songs': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}], 'year': '1980'}, {'songs': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}], 'year': '1981'}]

# %%
import urllib.request 
import json

urlData = "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"

webUrl = urllib.request.urlopen(urlData)
print (webUrl.getcode())
if (webUrl.getcode() == 200):
    data = webUrl.read()
    data = data.decode('utf-8') 
    print(data)
# Out:
# 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf642aa37686> in <module>()
#       8 if (webUrl.getcode() == 200):
#       9     data = webUrl.read()
# ---> 10     data = data.decode(utf-8)
#      11     print(data)
#
# NameError: name 'utf' is not defined

# %%
import urllib.request 
import json

urlData = "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"

webUrl = urllib.request.urlopen(urlData)
print (webUrl.getcode())
if (webUrl.getcode() == 200):
    data = webUrl.read()
     
    print(data)
# Out:
# 200
# <html><head><meta charset="utf-8"></head><body><script>window.rbzns = {fiftyeightkb: 3600000, days_in_week : 1};</script><script>var h9U={'L6':function(U,b){return U!=b;},'t6':function(U,b){return U|b;},'R6':function(U,b){return U>>>b;},'l2':function(U,b){return U===b;},'T7H':(function(L7H){return (function(C7H,r7H){return (function(W7H){return {v7H:W7H};})(function(B7H){var R7H,E7H=0;for(var q7H=C7H;E7H<B7H["length"];E7H++){var X7H=r7H(B7H,E7H);R7H=E7H===0?X7H:R7H^X7H;}return R7H?q7H:!q7H;});})((function(c7H,J7H,P7H,f7H){var F7H=32;return c7H(L7H,F7H)-f7H(J7H,P7H)>F7H;})(parseInt,Date,(function(J7H){return (''+J7H)["substring"](1,(J7H+'')["length"]-1);})('_getTime2'),function(J7H,P7H){return new J7H()[P7H]();}),function(B7H,E7H){var O7H=parseInt(B7H["charAt"](E7H),16)["toString"](2);return O7H["charAt"](O7H["length"]-1);});})('6ia8u0v00'),'n2':function(U,b){return U==b;},'x2':function(U,b){return U&b;},'N0':function(U,b){return U&b;},'p6':function(U,b){return U|b;},'c3':function(U,b){return U<b;},'g5':function(U,b){return U<<b;},'W5':function(U,b){return U>b;},'e2':function(U,b){return U!==b;},'j0':function(U,b){return U<b;},'e1':function(U,b){return U<b;},'T6':function(U,b,D,k){return U|b|D|k;},'s6':function(U,b){return U<b;},'G7':function(U,b){return U>>b;},'k7':function(U,b){return U<b;},'p2':function(U,b){return U<b;},'C3':function(U,b){return U>b;},'B7':function(U,b){return U<<b;},'k5H':"push",'K2':function(U,b){return U&b;},'h0':function(U,b){return U<=b;},'C7':function(U,b){return U>>b;},'O1':"getTimezoneOffset",'S3':function(U,b){return U<b;},'z7':function(U,b){return U<=b;},'X3':function(U,b){return U<b;},'a5':function(U,b){return U&b;},'w3':function(U,b){return U|b;},'T7':function(U,b){return U<b;},'P6':function(U,b){return U%b;},'M0':function(U,b){return U&b;},'Y2':function(U,b){return U===b;},'R0':function(U,b){return U&b;},'u3':function(U,b){return U|b;},'k1':function(U,b){return U<b;},'J7':function(U,b){return U<<b;},'j6':function(U,b,D,k){return U|b|D|k;},'U2':function(U,b){return U!==b;},'I0':function(U,b){return U<=b;},'l5':function(U,b){return U&b;},'U3':function(U,b){return U==b;},'t3':function(U,b){return U<=b;},'r5':function(U,b){return U===b;},'e5':function(U,b){return U&b;},'F2':function(U,b){return U&b;},'z6':function(U,b){return U|b;},'B3':function(U,b){return U>=b;},'N7':function(U,b){return U==b;},'c7':function(U,b){return U<<b;},'s3':function(U,b){return U&b;},'d2H':"get",'p7':function(U,b){return U<<b;},'h3':function(U,b){return U!=b;},'U1':function(U,b){return U>>>b;},'x6':function(U,b){return U&b;},'M7':function(U,b){return U<<b;},'M6':function(U,b){return U|b;},'J3':function(U,b){return U&b;},'a2':function(U,b){return U-b;},'w5':function(U,b){return U<=b;},'n5':function(U,b){return U|b;},'D3':function(U,b){return U&b;},'K5':function(U,b){return U>>>b;},'u0':function(U,b,D,k){return U^b^D^k;},'m6':function(U,b,D){return U|b|D;},'X7':function(U,b){return U&b;},'s7':function(U,b){return U!=b;},'E5':function(U,b){return U&b;},'q6':function(U,b){return U&b;},'M3':function(U,b){return U>=b;},'Q3':function(U,b){return U>=b;},'f2':function(U,b){return U|b;},'W2':function(U,b){return U|b;},'P0':function(U,b){return U&b;},'I9':"undefined",'i6':function(U,b){return U<b;},'O0':function(U,b){return U<=b;},'Y5':function(U,b){return U&b;},'u7':function(U,b){return U>>b;},'k6':function(U,b){return U|b;},'j7':function(U,b){return U>>b;},'G0':function(U,b){return U>=b;},'d6':function(U,b){return U&b;},'r2':function(U,b){return U&b;},'S5':function(U,b){return U<=b;},'p2H':"Fingerprint",'Q8':"charCodeAt",'q0':function(U,b){return U<=b;},'n1':function(U,b){return U===b;},'T3':function(U,b){return U&b;},'l1':function(U,b){return U in b;},'j3':function(U,b){return U>b;},'p1':function(U,b){return U<b;},'d2':function(U,b){return U&b;},'V0':function(U,b){return U&b;},'L0':function(U,b){return U<=b;},'l9':"join",'t7':function(U,b){return U&b;},'H5':function(U,b){return U<<b;},'Y8':"plugins",'E2':function(U,b){return U&b; ...

# %%
# Out:
# 200
# b'<!--  jsp/performers/perf -->\r\n<!DOCTYPE html>\r\n<html xmlns:fb="http://ogp.me/ns/fb#">\r\n<head>\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge"> \r\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n\t<!-- /jsp/jsi/headerInit_Performer_Page -->\r\n<script>\r\n\r\n\tvar agent = navigator.userAgent.toLowerCase();\r\n\tif(agent.indexOf(\'android\') != -1 || agent.indexOf(\'iphone\') != -1 || agent.indexOf(\'ipad\') != -1){\r\n\t\tvar myUrl = window.location.href.toLowerCase();\r\n\t\tif(myUrl.indexOf("m.shironet.mako.co.il") == -1 && myUrl.indexOf("shironet.mako.co.il") != -1 )\r\n\t\t{\r\n\t\t\twindow.location = window.location.href.replace(\'shironet.mako\',\'m.shironet.mako\');\r\n\t\t}\r\n\t}\r\n\r\n</script>\r\n<meta name="expires" content="never" />\r\n<meta name="language" content="hebrew" />\r\n<meta name="distribution" content="Global" />\r\n<meta name="robots" content="index, follow" />\r\n\r\n<link rel="SHORTCUT ICON" href="/jsp/images/shironet.ico" />\r\n<link href="/jsp/css/global.css" rel="stylesheet" type="text/css" />\r\n<link href="/jsp/css/header.css" rel="stylesheet" type="text/css" />\r\n<link href="/jsp/css/talkbacks.css" rel="stylesheet" type="text/css" />\r\n<link href="/jsp/css/footer.css" rel="stylesheet" type="text/css" />\r\n<link href="/jsp/css/googleAds.css" rel="stylesheet"/>\r\n\r\n<script src="/js/ajax.js" language="javascript"></script>\r\n<script src="/js/general.js" language="javascript"></script>\r\n\r\n<script>\r\n\tvar pp_gemius_identifier;\r\n\tif(window.location.href.toLowerCase().indexOf("m.shironet.mako.co.il") != -1)\r\n\t{\r\n\t\tpp_gemius_identifier = new String(\'0sVLmWuU0FRF_zafrAOD6OV1jw6FZcMwd9fVSy3C_0f.Y7\');\r\n\t\tdocument.write(\'<script src="http://gail.hit.gemius.pl/xgemius_ls.js"><\\/script>\')\r\n\t}\r\n</script>\r\n\r\n<script>\r\n\tMM_preloadImages(\'/jsp/images/global_bg_top_left.gif\', \'/jsp/images/global_bg_top_right.gif\', \'/jsp/images/global_bg_left.gif\', \'/jsp/images/global_bg_right.gif\', \'/jsp/images/header_blue_bg_980.jpg\', \'/jsp/images/header_search_box_bg.jpg\', \'/jsp/images/global_main_td_shadow.jpg\', \'/jsp/images/global_bg_top_gray.gif\', \'/jsp/images/global_main_td_shadow.jpg\',\'/jsp/images/global_table_shadow_1020.gif\', \'/jsp/images/artist_menu_box.gif\', \'/jsp/images/artist_menu_box_hover.gif\');\r\n</script>\r\n<script>if (location.hostname[0] != \'m\'){try{(function(){function v(a,e){var b=a.length,c=e.length;if(b<c)return v(e,a);for(var f=0,d=[],g=0;g<c;g++)f+=a[g]+e[g],d[g]=f&268435455,f>>>=28;for(;g<b;g++)f+=a[g],d[g]=f&268435455,f>>>=28;f&&(d[g]=f);return d}function m(a,e){var b=a.length,c=e.length,f=0,d=[];if(c>b)return[];if(c==b){if(e[c-1]>a[c-1])return[];if(1==c)return[a[0]-e[0]]}for(var g=0;g<c;g++)f+=a[g]-e[g],d[g]=f&268435455,f>>=28;for(;g<b;g++)f+=a[g],d[g]=f&268435455,f>>=28;if(f)return[];if(d[g-1])return d;for(;1<g&&0==d[g-1];)g--;\r\nreturn d.slice(0,g)}function n(a,e){e=e.concat([0]);var b=a.length,c=e.length,f=[],d,g,h,k,p,l,m,u,n,C;for(d=b+c;0<=d;d--)f[d]=0;for(d=0;d<b;d++)if(g=a[d])for(h=0,u=g>>14,m=g&16383,k=d,g=0;g<c;g++,k++)p=e[g],l=p>>14,p&=16383,C=p*u+m*l,n=C>>14,C&=16383,h+=f[k]+m*p+(C<<14),f[k]=h&268435455,h=(h>>28)+l*u+n;d=f.length;if(f[d-1])return f;for(;1<d&&0==f[d-1];)d--;return f.slice(0,d)}function D(a){for(var e=[];0<a--;)e[a]=0;return e}function w(a,e,b){for(var c=0;0<=e&&0<b--;)c=268435456*c+a[e--];return c}\r\nfunction A(a,e){var b=a.length-1,c=e.length-1,f=b-c;if(b<c||b==c&&(a[b]<e[b]||0<b&&a[b]==e[b]&&a[b-1]<e[b-1]))return l.q=[0],l.mod=a,l;if(b==c&&4>w(a,c,2)/w(e,c,2)){for(var d=0;;){c=m(a,e);if(0==c.length)break;a=c;d++}l.q=[d];l.mod=a;return l}var g,h;h=Math.floor(Math.log(e[c])/K)+1;if(g=28-h){a=a.concat();e=e.concat();for(k=c;0<k;k--)e[k]=e[k]<<g&268435455|e[k-1]>>h;e[0]=e[0]<<g&268435455;a[b]&268435455<<h&268435455&&(a[++b]=0,f++);for(k=b;0<k;k--)a[k]=a[k]<<g&268435455|a[k-1]>>h;a[0]=a[0]<<g&268435455}var k,\r\np,z,d=D(f+1);for(z=D(f).concat(e);;){p=m(a,z) ...

# %%
import urllib.request 
import json
import requests

urlData = "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"

webUrl = urllib.request.urlopen(urlData)
print (webUrl.getcode())
if (webUrl.getcode() == 200):
    data = webUrl.read()
    data = data.decode('utf-8') 
    print(data)
# Out:
# 200
# <html><head><meta charset="utf-8"></head><body><script>window.rbzns = {fiftyeightkb: 3600000, days_in_week : 1};</script><script>var h9U={'L6':function(U,b){return U!=b;},'t6':function(U,b){return U|b;},'R6':function(U,b){return U>>>b;},'l2':function(U,b){return U===b;},'T7H':(function(L7H){return (function(C7H,r7H){return (function(W7H){return {v7H:W7H};})(function(B7H){var R7H,E7H=0;for(var q7H=C7H;E7H<B7H["length"];E7H++){var X7H=r7H(B7H,E7H);R7H=E7H===0?X7H:R7H^X7H;}return R7H?q7H:!q7H;});})((function(c7H,J7H,P7H,f7H){var F7H=32;return c7H(L7H,F7H)-f7H(J7H,P7H)>F7H;})(parseInt,Date,(function(J7H){return (''+J7H)["substring"](1,(J7H+'')["length"]-1);})('_getTime2'),function(J7H,P7H){return new J7H()[P7H]();}),function(B7H,E7H){var O7H=parseInt(B7H["charAt"](E7H),16)["toString"](2);return O7H["charAt"](O7H["length"]-1);});})('6ia8u0v00'),'n2':function(U,b){return U==b;},'x2':function(U,b){return U&b;},'N0':function(U,b){return U&b;},'p6':function(U,b){return U|b;},'c3':function(U,b){return U<b;},'g5':function(U,b){return U<<b;},'W5':function(U,b){return U>b;},'e2':function(U,b){return U!==b;},'j0':function(U,b){return U<b;},'e1':function(U,b){return U<b;},'T6':function(U,b,D,k){return U|b|D|k;},'s6':function(U,b){return U<b;},'G7':function(U,b){return U>>b;},'k7':function(U,b){return U<b;},'p2':function(U,b){return U<b;},'C3':function(U,b){return U>b;},'B7':function(U,b){return U<<b;},'k5H':"push",'K2':function(U,b){return U&b;},'h0':function(U,b){return U<=b;},'C7':function(U,b){return U>>b;},'O1':"getTimezoneOffset",'S3':function(U,b){return U<b;},'z7':function(U,b){return U<=b;},'X3':function(U,b){return U<b;},'a5':function(U,b){return U&b;},'w3':function(U,b){return U|b;},'T7':function(U,b){return U<b;},'P6':function(U,b){return U%b;},'M0':function(U,b){return U&b;},'Y2':function(U,b){return U===b;},'R0':function(U,b){return U&b;},'u3':function(U,b){return U|b;},'k1':function(U,b){return U<b;},'J7':function(U,b){return U<<b;},'j6':function(U,b,D,k){return U|b|D|k;},'U2':function(U,b){return U!==b;},'I0':function(U,b){return U<=b;},'l5':function(U,b){return U&b;},'U3':function(U,b){return U==b;},'t3':function(U,b){return U<=b;},'r5':function(U,b){return U===b;},'e5':function(U,b){return U&b;},'F2':function(U,b){return U&b;},'z6':function(U,b){return U|b;},'B3':function(U,b){return U>=b;},'N7':function(U,b){return U==b;},'c7':function(U,b){return U<<b;},'s3':function(U,b){return U&b;},'d2H':"get",'p7':function(U,b){return U<<b;},'h3':function(U,b){return U!=b;},'U1':function(U,b){return U>>>b;},'x6':function(U,b){return U&b;},'M7':function(U,b){return U<<b;},'M6':function(U,b){return U|b;},'J3':function(U,b){return U&b;},'a2':function(U,b){return U-b;},'w5':function(U,b){return U<=b;},'n5':function(U,b){return U|b;},'D3':function(U,b){return U&b;},'K5':function(U,b){return U>>>b;},'u0':function(U,b,D,k){return U^b^D^k;},'m6':function(U,b,D){return U|b|D;},'X7':function(U,b){return U&b;},'s7':function(U,b){return U!=b;},'E5':function(U,b){return U&b;},'q6':function(U,b){return U&b;},'M3':function(U,b){return U>=b;},'Q3':function(U,b){return U>=b;},'f2':function(U,b){return U|b;},'W2':function(U,b){return U|b;},'P0':function(U,b){return U&b;},'I9':"undefined",'i6':function(U,b){return U<b;},'O0':function(U,b){return U<=b;},'Y5':function(U,b){return U&b;},'u7':function(U,b){return U>>b;},'k6':function(U,b){return U|b;},'j7':function(U,b){return U>>b;},'G0':function(U,b){return U>=b;},'d6':function(U,b){return U&b;},'r2':function(U,b){return U&b;},'S5':function(U,b){return U<=b;},'p2H':"Fingerprint",'Q8':"charCodeAt",'q0':function(U,b){return U<=b;},'n1':function(U,b){return U===b;},'T3':function(U,b){return U&b;},'l1':function(U,b){return U in b;},'j3':function(U,b){return U>b;},'p1':function(U,b){return U<b;},'d2':function(U,b){return U&b;},'V0':function(U,b){return U&b;},'L0':function(U,b){return U<=b;},'l9':"join",'t7':function(U,b){return U&b;},'H5':function(U,b){return U<<b;},'Y8':"plugins",'E2':function(U,b){return U&b; ...

# %%
import urllib.request 
import json
import requests

urlData = "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"

r = requests.get(urlData)
print r.text
# Out:
#   File "<ipython-input-6-d242f3ef104c>", line 8
#     print r.text
#           ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
import urllib.request 
import json
import requests

urlData = "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"

r = requests.get(urlData)
print (r.text)
# Out:
#   File "<ipython-input-7-d242f3ef104c>", line 8
#     print r.text
#           ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
import urllib.request 
import json
import requests

urlData = "https://github.com/timeline.json"

r = requests.get(urlData)
print (r.text)
# Out:
# <html><head><meta charset="utf-8"></head><body><script>window.rbzns = {fiftyeightkb: 3600000, days_in_week : 1};</script><script>var h9U={'L6':function(U,b){return U!=b;},'t6':function(U,b){return U|b;},'R6':function(U,b){return U>>>b;},'l2':function(U,b){return U===b;},'T7H':(function(L7H){return (function(C7H,r7H){return (function(W7H){return {v7H:W7H};})(function(B7H){var R7H,E7H=0;for(var q7H=C7H;E7H<B7H["length"];E7H++){var X7H=r7H(B7H,E7H);R7H=E7H===0?X7H:R7H^X7H;}return R7H?q7H:!q7H;});})((function(c7H,J7H,P7H,f7H){var F7H=32;return c7H(L7H,F7H)-f7H(J7H,P7H)>F7H;})(parseInt,Date,(function(J7H){return (''+J7H)["substring"](1,(J7H+'')["length"]-1);})('_getTime2'),function(J7H,P7H){return new J7H()[P7H]();}),function(B7H,E7H){var O7H=parseInt(B7H["charAt"](E7H),16)["toString"](2);return O7H["charAt"](O7H["length"]-1);});})('6ia8u0v00'),'n2':function(U,b){return U==b;},'x2':function(U,b){return U&b;},'N0':function(U,b){return U&b;},'p6':function(U,b){return U|b;},'c3':function(U,b){return U<b;},'g5':function(U,b){return U<<b;},'W5':function(U,b){return U>b;},'e2':function(U,b){return U!==b;},'j0':function(U,b){return U<b;},'e1':function(U,b){return U<b;},'T6':function(U,b,D,k){return U|b|D|k;},'s6':function(U,b){return U<b;},'G7':function(U,b){return U>>b;},'k7':function(U,b){return U<b;},'p2':function(U,b){return U<b;},'C3':function(U,b){return U>b;},'B7':function(U,b){return U<<b;},'k5H':"push",'K2':function(U,b){return U&b;},'h0':function(U,b){return U<=b;},'C7':function(U,b){return U>>b;},'O1':"getTimezoneOffset",'S3':function(U,b){return U<b;},'z7':function(U,b){return U<=b;},'X3':function(U,b){return U<b;},'a5':function(U,b){return U&b;},'w3':function(U,b){return U|b;},'T7':function(U,b){return U<b;},'P6':function(U,b){return U%b;},'M0':function(U,b){return U&b;},'Y2':function(U,b){return U===b;},'R0':function(U,b){return U&b;},'u3':function(U,b){return U|b;},'k1':function(U,b){return U<b;},'J7':function(U,b){return U<<b;},'j6':function(U,b,D,k){return U|b|D|k;},'U2':function(U,b){return U!==b;},'I0':function(U,b){return U<=b;},'l5':function(U,b){return U&b;},'U3':function(U,b){return U==b;},'t3':function(U,b){return U<=b;},'r5':function(U,b){return U===b;},'e5':function(U,b){return U&b;},'F2':function(U,b){return U&b;},'z6':function(U,b){return U|b;},'B3':function(U,b){return U>=b;},'N7':function(U,b){return U==b;},'c7':function(U,b){return U<<b;},'s3':function(U,b){return U&b;},'d2H':"get",'p7':function(U,b){return U<<b;},'h3':function(U,b){return U!=b;},'U1':function(U,b){return U>>>b;},'x6':function(U,b){return U&b;},'M7':function(U,b){return U<<b;},'M6':function(U,b){return U|b;},'J3':function(U,b){return U&b;},'a2':function(U,b){return U-b;},'w5':function(U,b){return U<=b;},'n5':function(U,b){return U|b;},'D3':function(U,b){return U&b;},'K5':function(U,b){return U>>>b;},'u0':function(U,b,D,k){return U^b^D^k;},'m6':function(U,b,D){return U|b|D;},'X7':function(U,b){return U&b;},'s7':function(U,b){return U!=b;},'E5':function(U,b){return U&b;},'q6':function(U,b){return U&b;},'M3':function(U,b){return U>=b;},'Q3':function(U,b){return U>=b;},'f2':function(U,b){return U|b;},'W2':function(U,b){return U|b;},'P0':function(U,b){return U&b;},'I9':"undefined",'i6':function(U,b){return U<b;},'O0':function(U,b){return U<=b;},'Y5':function(U,b){return U&b;},'u7':function(U,b){return U>>b;},'k6':function(U,b){return U|b;},'j7':function(U,b){return U>>b;},'G0':function(U,b){return U>=b;},'d6':function(U,b){return U&b;},'r2':function(U,b){return U&b;},'S5':function(U,b){return U<=b;},'p2H':"Fingerprint",'Q8':"charCodeAt",'q0':function(U,b){return U<=b;},'n1':function(U,b){return U===b;},'T3':function(U,b){return U&b;},'l1':function(U,b){return U in b;},'j3':function(U,b){return U>b;},'p1':function(U,b){return U<b;},'d2':function(U,b){return U&b;},'V0':function(U,b){return U&b;},'L0':function(U,b){return U<=b;},'l9':"join",'t7':function(U,b){return U&b;},'H5':function(U,b){return U<<b;},'Y8':"plugins",'E2':function(U,b){return U&b; ...

# %%
import urllib.request 
import json
import requests

urlData = "http://www.azlyrics.com/p/postmalone.html#44329"

r = requests.get(urlData)
print (r.text)
# Out:
# {"message":"Hello there, wayfaring stranger. If you’re reading this then you probably didn’t see our blog post a couple of years back announcing that this API would go away: http://git.io/17AROg Fear not, you should be able to get what you need from the shiny new Events API instead.","documentation_url":"https://developer.github.com/v3/activity/events/#list-public-events"}

# %%
import urllib.request 
import json
import requests

urlData = "http://www.songlyrics.com/j-cole/who-dat-lyrics/"

r = requests.get(urlData)
print (r.text)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                     # otherwise it looks like a programming error was the cause.
# --> 393                     six.raise_from(e, None)
#     394         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     388                 try:
# --> 389                     httplib_response = conn.getresponse()
#     390                 except Exception as e:
#
# C:\Users\Niv\Anaconda3\lib\http\client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# C:\Users\Niv\Anaconda3\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# C:\Users\Niv\Anaconda3\lib\http\client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     639             retries = retries.increment(method, url, error=e, _pool=self,
# --> 640                                         _stacktrace=sys.exc_info()[2])
#     641             retries.sleep()
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     260             if read is False:
# --> 261                 raise six.reraise(type(error), error, _stacktrace)
#     262             elif read is not None:
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                     # otherwise it looks like a programming error was the cause.
# --> 393                     six.raise_from(e, None)
#     394         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     388                 try:
# --> 389                     httplib_response = conn.getresponse()
#     390                 except Exception as e:
#
# C:\Users\Niv\Anaconda3\lib\http\client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# C:\Users\Niv\Anaconda3\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# C:\Users\Niv\Anaconda3\lib\http\client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-10-89b5e0f12bd1> in <module>()
#       5 urlData = "http://www.azlyrics.com/p/postmalone.html#44329"
#       6
# ----> 7 r = requests.get(urlData)
#       8 print (r.text)
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# C:\Users\Niv\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     471
#     472         except (ProtocolError, socket.error) as err:
# --> 473             raise ConnectionError(err, request=request)
#     474
#     475         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
import urllib.request 
import json
import requests

urlData = "http://www.songlyrics.com/j-cole/who-dat-lyrics/"

r = requests.get(urlData)
print (r.text)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml" lang="en-US">
# <head>
# 	<title>J. COLE - WHO DAT LYRICS</title>
# 	<meta http-equiv="content-type" content="text/html; charset=utf-8" />
# 	<meta name="description" content="J. Cole - Who Dat Lyrics. Who dat, who dat? Who dat, who dat? Who dat, who dat? Hey, who dat, who dat? That nigga you been waitin' for I mean the shit was all bad ju" />
#
# 	<meta name="msvalidate.01" content="CF28C9C2E5FDBD5C7CA7F6FE394BD121" />
#         	<meta name="robots" content="noydir, noodp" />
#         	<meta property="fb:admins" content="31113169,100000933112467,1383859676" />
# 	<meta name="fb:app_id" content="1418134321780018" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1"> <!-- viewport -->
#
# 	<meta property="og:title" content="Who Dat - J. Cole"/>
# 	<meta property="og:type" content="song"/>
# 	<meta property="og:url" content="http://www.songlyrics.com/j-cole/who-dat-lyrics/"/>
# 	<meta property="og:image" content="http://www.songlyrics.com/images/album-nophoto-fb.gif"/>
# 	<meta property="og:site_name" content="SongLyrics.com"/>
# 	<link rel="preconnect" href="http://www.songlyrics.com" />
#         <link rel="dns-prefetch" href="//cdn2.songlyricscom.netdna-cdn.com" />
#         <link rel="dns-prefetch" href="//cdn1.songlyricscom.netdna-cdn.com" />
#         <link rel="dns-prefetch" href="//news.songlyricscom.netdna-cdn.com" />
#         <link rel="dns-prefetch" href="//pagead2.googlesyndication.com" />
# 	<link rel="dns-prefetch" href="//googleads.g.doubleclick.net" />
#
# 	<link rel="icon" href="favicon.ico" type="image/ico" />
# 	<link href="css/global.css" rel="stylesheet" type="text/css" />
#
# 		 <link rel="stylesheet" type="text/css" href="http://www.songlyrics.com/css/icomment.css" />
#
# 	<script src="js/jquery.min.js" type="text/javascript"></script>
#
#
#
#
#
# <script type="text/javascript">
# var rangy;rangy=rangy||function(){function h(c,d){var e=typeof c[d];return e==b||!(e!=a||!c[d])||"unknown"==e}function i(b,c){return!(typeof b[c]!=a||!b[c])}function j(a,b){return typeof a[b]!=c}function k(a){return function(b,c){for(var d=c.length;d--;)if(!a(b,c[d]))return!1;return!0}}function o(a){return a&&l(a,g)&&n(a,f)}function p(a){return i(a,"body")?a.body:a.getElementsByTagName("body")[0]}function s(a){i(window,"console")&&h(window.console,"log")&&window.console.log(a)}function t(a,b){b?window.alert(a):s(a)}function u(a){r.initialized=!0,r.supported=!1,t("Rangy is not supported on this page in your browser. Reason: "+a,r.config.alertOnFail)}function v(a){t("Rangy warning: "+a,r.config.alertOnWarn)}function y(a){return a.message||a.description||String(a)}function z(){if(!r.initialized){var a,b=!1,c=!1;h(document,"createRange")&&(a=document.createRange(),l(a,e)&&n(a,d)&&(b=!0),a.detach());var f=p(document);if(!f||"body"!=f.nodeName.toLowerCase())return u("No body element found"),void 0;if(f&&h(f,"createTextRange")&&(a=f.createTextRange(),o(a)&&(c=!0)),!b&&!c)return u("Neither Range nor TextRange are available"),void 0;r.initialized=!0,r.features={implementsDomRange:b,implementsTextRange:c};var g,i;for(var j in q)(g=q[j])instanceof C&&g.init();for(var k=0,m=x.length;m>k;++k)try{x[k](r)}catch(t){i="Rangy init listener threw an exception. Continuing. Detail: "+y(t),s(i)}}}function B(a){a=a||window,z();for(var b=0,c=A.length;c>b;++b)A[b](a)}function C(a,b){this.name=a,this.initialized=!1,this.supported=!1,this.init=b}var a="object",b="function",c="undefined",d=["startContainer","startOffset","endContainer","endOffset","collapsed","commonAncestorContainer"],e=["setStart","setStartBefore","setStartAfter","setEnd","setEndBefore","setEndAfter","collapse","selectNode","selectNodeContents","compareBoundaryPoints","deleteContents","extractContents","cloneContents","insertNode","surroundContents","cloneRange","toString","detach"],f=["boundingHeight","boundingLeft","boundingTop","boundingWidth","htmlText","text"],g=["collapse","compareEndPoints","duplicate","moveToElementText","parentElement","select","setEndPoint","getBoundingClientRect"],l=k(h),m=k(i),n=k(j),q={},r={version:"1.3alpha.772",initialized:!1,supported:!0,util:{isHostMethod:h,isHostObject:i,isHostProperty:j,areHostMethods:l,areHostObjects:m,areHostProperties:n,isTextRange:o,getBody:p},features:{},modules:q,config:{alertOnFail:!0,alertOnWarn:!1,preferTextRange:!1}};r.fail=u,r.warn=v,{}.hasOwnProperty?r.util.extend=function(a,b,c){var d,e;for(var f in b)b.hasOwnProperty(f)&&(d=a[f],e=b[f],c&&null!==d&&"object"==typeof d&&null!==e&&"object"==typeof e&&r.util.extend(d,e,!0),a[f]=e);return a}:u("hasOwnProperty not supported"),function(){var a=document.createElement("div");a.appendChild(document.createElement("span"));var c,b=[].slice;try{1==b.call(a.childNodes,0)[0].nodeType&&(c=function(a){return b.call(a,0)})}catch(d){}c||(c=function(a){for(var b=[],c=0,d=a.length;d>c;++c)b[c]=a[c];return b}),r.util.toArray=c}();var w;h(document,"addEventListener")?w=function(a,b,c){a.addEventListener(b,c,!1)}:h(document,"attachEvent")?w=function(a,b,c){a.attachEvent("on"+b,c)}:u("Document does not have required addEventListener or attachEvent method"),r.util.addListener=w;var x=[];r.init=z,r.addInitListener=function(a){r.initialized?a(r):x.push(a)};var A=[];r.addCreateMissingNativeApiListener=function(a){A.push(a)},r.createMissingNativeApi=B,C.prototype={fail:function(a){throw this.initialized=!0,this.supported=!1,new Error("Module '"+this.name+"' failed to load: "+a)},warn:function(a){r.warn("Module "+this.name+": "+a)},deprecationNotice:function(a,b){r.warn("DEPRECATED: "+a+" in module "+this.name+"is deprecated. Please use "+b+" instead")},createError:function(a){return new Error("Error in Rangy "+this.name+" module: "+a)}},r.createModule=function(a,b){var c=new C(a,function(){if(!c.initialized){c.initialized=!0;try{b(r,c),c.supported=!0}catch(d){var e="Module '"+a+"' failed to load: "+ ...
# }();"undefined"==typeof p.Range&&(p.Range=d),a.createNativeRange=function(a){return a=j(a,b,"createNativeRange"),i(a).createTextRange()},a.WrappedRange=d}}a.createRange=function(c){return c=j(c,b,"createRange"),new a.WrappedRange(a.createNativeRange(c))},a.createRangyRange=function(a){return a=j(a,b,"createRangyRange"),new h(a)},a.createIframeRange=function(c){return b.deprecationNotice("createIframeRange()","createRange(iframeEl)"),a.createRange(c)},a.createIframeRangyRange=function(c){return b.deprecationNotice("createIframeRangyRange()","createRangyRange(iframeEl)"),a.createRangyRange(c)},a.addCreateMissingNativeApiListener(function(b){var c=b.document;"undefined"==typeof c.createRange&&(c.createRange=function(){return a.createRange(c)}),c=b=null})}),rangy.createModule("WrappedSelection",function(a,b){function r(a){return"string"==typeof a?"backward"==a:!!a}function s(a,c){if(a){if(d.isWindow(a))return a;if(a instanceof T)return a.win;var e=d.getContentDocument(a,b,c);return d.getWindow(e)}return window}function t(a){return s(a,"getWinSelection").getSelection()}function u(a){return s(a,"getDocSelection").document.selection}function I(a,b,c){var d=c?"end":"start",e=c?"start":"end";a.anchorNode=b[d+"Container"],a.anchorOffset=b[d+"Offset"],a.focusNode=b[e+"Container"],a.focusOffset=b[e+"Offset"]}function J(a){var b=a.nativeSelection;a.anchorNode=b.anchorNode,a.anchorOffset=b.anchorOffset,a.focusNode=b.focusNode,a.focusOffset=b.focusOffset}function K(a){a.anchorNode=a.focusNode=null,a.anchorOffset=a.focusOffset=0,a.rangeCount=0,a.isCollapsed=!0,a._ranges.length=0}function L(b){var c;return b instanceof g?(c=a.createNativeRange(b.getDocument()),c.setEnd(b.endContainer,b.endOffset),c.setStart(b.startContainer,b.startOffset)):b instanceof h?c=b.nativeRange:m.implementsDomRange&&b instanceof d.getWindow(b.startContainer).Range&&(c=b),c}function M(a){if(!a.length||1!=a[0].nodeType)return!1;for(var b=1,c=a.length;c>b;++b)if(!d.isAncestorOf(a[0],a[b]))return!1;return!0}function N(a){var c=a.getNodes();if(!M(c))throw b.createError("getSingleElementFromRange: range "+a.inspect()+" did not consist of a single element");return c[0]}function O(a){return!!a&&"undefined"!=typeof a.text}function P(a,b){var c=new h(b);a._ranges=[c],I(a,c,!1),a.rangeCount=1,a.isCollapsed=c.collapsed}function Q(b){if(b._ranges.length=0,"None"==b.docSelection.type)K(b);else{var c=b.docSelection.createRange();if(O(c))P(b,c);else{b.rangeCount=c.length;for(var d,e=o(c.item(0)),f=0;f<b.rangeCount;++f)d=a.createRange(e),d.selectNode(c.item(f)),b._ranges.push(d);b.isCollapsed=1==b.rangeCount&&b._ranges[0].collapsed,I(b,b._ranges[b.rangeCount-1],!1)}}}function R(a,c){for(var d=a.docSelection.createRange(),e=N(c),f=o(d.item(0)),g=p(f).createControlRange(),h=0,i=d.length;i>h;++h)g.add(d.item(h));try{g.add(e)}catch(j){throw b.createError("addRange(): Element within the specified Range could not be added to control selection (does it have layout?)")}g.select(),Q(a)}function T(a,b,c){this.nativeSelection=a,this.docSelection=b,this._ranges=[],this.win=c,this.refresh()}function U(a){a.win=a.anchorNode=a.focusNode=a._ranges=null,a.rangeCount=a.anchorOffset=a.focusOffset=0,a.detached=!0}function W(a,b){for(var d,e,c=V.length;c--;)if(d=V[c],e=d.selection,"deleteAll"==b)U(e);else if(d.win==a)return"delete"==b?(V.splice(c,1),!0):e;return"deleteAll"==b&&(V.length=0),null}function Z(a,c){for(var g,d=o(c[0].startContainer),e=p(d).createControlRange(),f=0;rangeCount>f;++f){g=N(c[f]);try{e.add(g)}catch(h){throw b.createError("setRanges(): Element within the one of the specified Ranges could not be added to control selection (does it have layout?)")}}e.select(),Q(a)}function cb(a,b){if(a.win.document!=o(b))throw new i("WRONG_DOCUMENT_ERR")}function db(b){return function(c,d){var e;this.rangeCount?(e=this.getRangeAt(0),e["set"+(b?"Start":"End")](c,d)):(e=a.createRange(this.win.document),e.setStartAndEnd(c,d)),this.setSingleRange(e,this.isBackward())}}function eb(a){var b=[],c=new j(a.anc ...
# </script>
#
#
# 	<!-- head info -->
#
#
#
#
# <script type="text/javascript">
# 	$(function(){
# 		$.superbox();
# 	});
# </script>
#
# <script type="text/javascript">
# //<![CDATA[
#   $(document).ready(function() {
# 	function addMega(){
# 	$(this).addClass("hovering");
# 	$($(this).find("h2 a")).addClass("hover");
# 	}
# 	function removeMega(){
# 	$(this).removeClass("hovering");
# 	$($(this).find("h2 a")).removeClass("hover");
# 	}
#   var megaConfig = {
#      interval: 30,
#      sensitivity: 4,
#      over: addMega,
#      timeout: 30,
#      out: removeMega
#   };
#   $("li.mega").hoverIntent(megaConfig)
#   });
#  //]]>
# </script>
#
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-235369-1']);
#   _gaq.push(['_setDomainName', 'songlyrics.com']);
#   _gaq.push(['_trackPageview']);
#   _gaq.push(['_trackPageLoadTime']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script>
#
# <!-- Quantcast Tag, part 1 -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
# </script>
# <!-- End Quantcast tag, part 1 -->
#
#
#
#
# <script src="http://tags.evolvemediallc.com/websites/evolve_tags/14217"></script>
#
#
# <!-- Place in head part widget:slyr002 -->
# <script type="text/javascript">
#
#     var sbElementInterval = setInterval(function(){sbElementCheck()}, 50);
#
#     function sbElementCheck() {
#
#         var targetedElement = document.getElementById('ingageunit');
#         if(targetedElement) {
#             clearInterval(sbElementInterval);
#             (function(d) {
#                 var js, s = d.getElementsByTagName('script')[0];
#                 js = d.createElement('script');
#                 js.async = true;
#                 js.onload = function(e) {
#                     SbInGageWidget.init({
#                         partnerId : 4439,
#                         widgetId : 'slyr002',
#                         cmsPath : 'http://cms.springboardplatform.com'
#                     });
#                 }
#                 js.src = "http://cdn.springboardplatform.com/storage/js/ingage/apingage.min.js";
#                 s.parentNode.insertBefore(js, s);
#             })(window.document);
#         }
#     }
# </script>
#
# </head>
# <body  >
# <div id='fb-root'></div>
# <script>
#
# $(window).load(function () {
#
#
#
# 		setTimeout (function(){
# 			$("#jangoPlayer2").attr('src',$("#jangoPlayer2").attr('longdesc'));
# 			},3000);
#
#
#
# });
#
#
# </script>
#
# <div id="header">
#
# <div id="headernav">
# 	<div class="headinner">
#
# 		<ul class="menu floatleft">
# 			<li class="mega">
# 			  <h2><a href="/">Lyrics</a></h2>
# 				<div>
# 					<p><a href="/top-songs-lyrics.html">Popular Song Lyrics</a></p>
# 					<p><a href="/top100.php">Billboard Hot 100</a></p>
# 					<p><a href="/top-upcoming-songs.html">Upcoming Lyrics</a></p>
# 					<p><a href="/latestAddedSongs">Recently Added</a></p>
# 					<p class="menu-hr"></p>
# 					<p><a href="/news/top-songs/2011/">Top Lyrics of 2011</a></p>
# 					<p><a href="/news/top-songs/2010/">Top Lyrics of 2010</a></p>
# 					<p><a href="/news/top-songs/2009/">Top Lyrics of 2009</a></p>
# 					<p><a href="/news/top-songs/all-time/">More &raquo;</a></p>
# 				</div>
# 			</li>
# 			<li class="mega">
# 			  <h2><a href="/top-artists-lyrics.html">Artists</a></h2>
# 				<div>
# 					<p><a href="/top-artists-lyrics.html">Popular Artists</a></p>
# 					<p><a href="/a/">Artists A-Z</a></p>
# 					<p class="menu-hr"></p>
# 					<p><a href="/top-albums-lyrics.html">Popular Albums</a></p>
# 					<p><a href="/top-upcoming-albums.html">Upcoming Albums</a></p>
# 					<p class="menu-hr"></p>
# 					<p><a href="/adele-lyrics/">Adele</a></p>
# 					<p><a href="/rihanna-lyrics/">Rihanna</a></p>
# 					<p><a href="/katy-perry-lyrics/">Katy Perry</a></p>
# 					<p><a href="/lady-gaga-lyrics/">Lady Gaga</a></p>
# 					<p><a href="/lil-wayne-lyrics/">Lil Wayne</a></p>
#
# 				</div>
# 			</li>
# 			<li class="mega">
# 			  <h2><a href="/musicgenres.php">Genres</a></h2>
# 				<div>
# 					<p><a href="/rock-lyrics.php" title="Rock Lyrics">Rock</a></p>
# 					<p><a href="/r-and-b-lyrics.php" title="R&B Lyrics">R&amp;B</a></p>
# 					<p><a href="/country-music-lyrics.php" title="Country Lyrics">Country</a></p>
# 					<p><a href="/hip-hop-rap-lyrics.php" title="Hip Hop and Rap Lyrics">Hip Hop/Rap</a></p>
# 					<p><a href="/pop-lyrics.php" title="Pop Lyrics">Pop</a></p>
# 					<p><a href="/christian-lyrics.php" title="Christian Lyrics">Christian</a></p>
# 					<p><a href="/dance-lyrics.php" title="Dance Lyrics">Dance</a></p>
# 					<p><a href="/latin-lyrics.php" title="Latin Lyrics">Latin</a></p>
# 					<p class="menu-hr"></p>
# 					<p><a href="/musicgenres.php" title="All Genre Charts">All Genres &raquo;</a></p>
# 				</div>
# 			</li>
#
# 			<li class="mega">
# 			  <h2><a href="/news/">News</a></h2>
# 				<div>
# 					<p><a href="/news/">All News</a></p>
# 					<p><a href="/news/category/news-roundup/">Daily Roundup</a></p>
# 				</div>
# 			</li>
#
# 			<li class="mega">
# 				<h2><a href="/news/album-reviews/">Reviews</a></h2>
# 				<div>
# 			  	<p><a href="/news/album-reviews/">Album Reviews</a></p>
# 			  	<p><a href="/news/category/song-reviews/">Song Reviews</a></p>
# 			  </div>
# 			</li>
#
# 			<li class="mega">
# 			  <h2><a href="/news/category/spotlight/">Spotlight</a></h2>
# 			</li>
#
# 		</ul>
# 				<p class="login-menu"><a class="btn" href="/member-login.php" rel="nofollow">Sign In</a><a class="btn" rel="nofollow" href="/member-register.php">Register</a></p>
# 				<ul class="menu floatright clearright">
# 			<li class="mega">
# 				<h2><a href="https://www.facebook.com/SongLyrics">Facebook</a></h2>
# 			</li>
# 			<li>
# 				<h2><a href="/news/advertise/">Advertise</a></h2>
# 			</li>
# 			<li class="lasttab">
# 				<h2><a href="/news/submit-lyrics/">Submit Lyrics</a></h2>
# 			</li>
# 		</ul>
#
#
# 	</div><!-- end headerinner -->
# </div><!-- end headernav -->
#
#
# <!-- HEADERNAV MOBILE -->
#
# <div id="headernav-mobile">
# 	<div class="headinner">
#
# 		<nav id="nav" role="navigation">
# 		    <a href="#nav" title="Show navigation">Show navigation
# 		    	<i class="line-1 line"></i>
# 		    	<i class="line-2 line"></i>
# 		    	<i class="line-3 line"></i>
# 		    </a>
# 		    <a href="#" class="hide" title="Hide navigation">Hide navigation
# 		    	<i class="line-1 line"></i>
# 		    	<i class="line-2 line"></i>
# 		    	<i class="line-3 line"></i>
# 		    </a>
# 		    <ul>
# 		        <li><a href="/" aria-haspopup="true">Lyrics</a>
# 		            <ul>
# 		                <li><a href="/top-songs-lyrics.html">Popular Song Lyrics</a></li>
# 		                <li><a href="/top100.php">Billboard Hot 100</a></li>
# 		                <li><a href="/top-upcoming-songs.html">Upcoming Lyrics</a></li>
# 		                <li><a href="/latestAddedSongs">Recently Added</a></li>
# 		                <li><a href="/news/top-songs/2011/">Top Lyrics of 2011</a></li>
# 		                <li><a href="/news/top-songs/2010/">Top Lyrics of 2010</a></li>
# 		                <li><a href="/news/top-songs/2009/">Top Lyrics of 2009</a></li>
# 		                <li><a href="/news/top-songs/all-time/">More &raquo;</a></li>
# 		            </ul>
# 		        </li>
# 		        <li><a href="/top-artists-lyrics.html" aria-haspopup="true">Artists</a>
# 		            <ul>
# 		                <li><a href="/top-artists-lyrics.html">Popular Artists</a></li>
# 		                <li><a href="/a/">Artists A-Z</a></li>
# 		                <li><a href="/top-albums-lyrics.html">Popular Albums</a></li>
# 		                <li><a href="/top-upcoming-albums.html">Upcoming Albums</a></li>
# 		                <li><a href="/adele-lyrics/">Adele</a></li>
# 		                <li><a href="/rihanna-lyrics/">Rihanna</a></li>
# 		                <li><a href="/katy-perry-lyrics/">Katy Perry</a></li>
# 		                <li><a href="/lady-gaga-lyrics/">Lady Gaga</a></li>
# 		                <li><a href="/lil-wayne-lyrics/">Lil Wayne</a></li>
# 		            </ul>
# 		        </li>
# 		        <li><a href="/musicgenres.php" aria-haspopup="true">Genres</a>
# 		            <ul>
# 		                <li><a href="/rock-lyrics.php" title="Rock Lyrics">Rock</a></li>
# 		                <li><a href="/r-and-b-lyrics.php" title="R&B Lyrics">R&amp;B</a></li>
# 		                <li><a href="/country-music-lyrics.php" title="Country Lyrics">Country</a></li>
# 		                <li><a href="/hip-hop-rap-lyrics.php" title="Hip Hop and Rap Lyrics">Hip Hop/Rap</a></li>
# 		                <li><a href="/pop-lyrics.php" title="Pop Lyrics">Pop</a></li>
# 		                <li><a href="/christian-lyrics.php" title="Christian Lyrics">Christian</a></li>
# 		                <li><a href="/dance-lyrics.php" title="Dance Lyrics">Dance</a></li>
# 		                <li><a href="/latin-lyrics.php" title="Latin Lyrics">Latin</a></li>
# 		                <li><a href="/musicgenres.php" title="All Genre Charts">All Genres &raquo;</a></li>
# 		            </ul>
# 		        </li>
# 		        <li><a href="/news/" aria-haspopup="true">News</a>
# 		            <ul>
# 		                <li><a href="/news/">All News</a></li>
# 		                <li><a href="/news/category/news-roundup/">Daily Roundup</a></li>
# 		            </ul>
# 		        </li>
# 		        <li><a href="/news/album-reviews/" aria-haspopup="true">Reviews</a>
# 		            <ul>
# 		                <li><a href="/news/album-reviews/">Album Reviews</a></li>
# 		                <li><a href="/news/category/song-reviews/">Song Reviews</a></li>
# 		            </ul>
# 		        </li>
# 		        <li><a href="/news/category/spotlight/" aria-haspopup="true">Spotlight</a></li>
# 		        <li><a href="https://www.facebook.com/SongLyrics" aria-haspopup="true">Facebook</a>
# 		        <li><a href="/news/advertise/" aria-haspopup="true">Advertise</a>
# 		        <li><a href="/news/submit-lyrics/" aria-haspopup="true">Submit Lyrics</a>
# 		        </li>
# 		    	<div id="header_search-mobile">
# 					<form name="searchForm" class="searchForm" method="get" action="/index.php">
# 					 <input type="hidden" name="section" value="search" />
#
# 					<fieldset>
# 						<input type="text" name="searchW" class="searchW input" value="Search artists, albums, and songs" onfocus="if(this.value=='Search artists, albums, and songs')(this.value='');" onblur="if(this.value=='')(this.value='Search artists, albums, and songs');" />
# 						<div class="submit-btn"><input type="submit" name="submit" value="Search" class="submit-input-wrapped searchSubmit" /></div>
# 					</fieldset>
# 					</form>
# 				</div>
# 		    </ul>
# 		</nav>
# 	</div><!-- end headerinner -->
# </div><!-- end headernav mobile  -->
#
#
# <div class="headinner">
#
#
# 	<a id="logo" href="/" title="Lyrics">Song Lyrics</a>
#
# 	<div id="header_search">
# 	<form name="searchForm" class="searchForm" method="get" action="/index.php">
# 	 <input type="hidden" name="section" value="search" />
#
# 	<fieldset>
# 		<input type="text" name="searchW" class="searchW input" value="Search artists, albums, and songs" onfocus="if(this.value=='Search artists, albums, and songs')(this.value='');" onblur="if(this.value=='')(this.value='Search artists, albums, and songs');" />
# 		<div class="submit-btn"><input type="submit" name="submit" value="Search" class="submit-input-wrapped searchSubmit" /></div>
# 	</fieldset>
# 	</form>
# 	</div>
#
# </div><!-- end headerinner -->
# </div><!-- end header -->
#
# <div id="wrapper">
#
# <div id="fbbox">
# 	<div id="fbbox-count">
# 		<span id="fbbox-total">
# 		55k
# 		</span>
# 	</div>
# 	<a id="fbbox-likebutton" target="_blank" href="https://www.facebook.com/SongLyrics">Like</a>
# </div>
#
#
# <script type="text/javascript" src="http://aka-cdn-ns.adtechus.com/dt/common/DAC.js"></script>
# <script type="text/javascript">
#          $(document).ready(function() {
#         	 	//$('a[href^="http://www.ringtonematcher"]').click(function() { pageTracker._trackEvent('Ringtone-songs', 'Click'); });
#         	 	$('.inner-player').click(function() {
#         	 		pageTracker._trackEvent('jango-player', 'Click');
#         	 	});
# ADTECH.config.page = { protocol: 'http', server: 'a.adtechus.com', network: '9869.1', pageid: 760151, params: { loc: '100' }};
#
# ADTECH.config.placements[3534291] = { sizeid: 3055, params: { alias: '3534291', target: '_blank' }};
# ADTECH.loadAd(3534291);
#
# ADTECH.config.placements[3534292] = { sizeid: 3055, params: { alias: '3534292', target: '_blank' }};
# ADTECH.loadAd(3534292);
#          });
# </script>
#
#
#
#
#
# <div class="top-ad-mobile">
# 	<script>
# 		/* Flex */
# 		cf_page_artist = "";
# 		cf_page_song = "";
# 		cf_adunit_id = "39381114";
# 		cf_flex = true;
# 	</script>
# 	<script src="//srv.clickfuse.com/showads/showad.js"></script>
# </div>
#
#
# <div class="masthead"></div>
#
# <div class="wrapper-inner footer-ad">
#
# 	<div class="topnav">
#
# 		<ul class="breadcrumb" itemscope itemtype="http://schema.org/BreadcrumbList"><li class="home" itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><a href="http://www.songlyrics.com/" itemprop="item"><span itemprop="name">Song Lyrics</span></a><meta itemprop="position" content="1" /></li><li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><a href="http://www.songlyrics.com/j/3/" itemprop="item"><span itemprop="name">Artists - J</span></a><meta itemprop="position" content="2" /></li><li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><a href="http://www.songlyrics.com/j-cole-lyrics/" itemprop="item"><span itemprop="name">J. Cole Lyrics</span></a><meta itemprop="position" content="3" /></li><li itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><a href="http://www.songlyrics.com/j-cole/who-dat/" itemprop="item"><span itemprop="name">Who Dat Album</span></a><meta itemprop="position" content="4" /></li><li class="current" itemprop="itemListElement" itemscope itemtype="http://schema.org/ListItem"><span itemprop="name">Who Dat Lyrics</span><meta itemprop="position" content="5" /></li></ul>
#
# 		<ul class="social-links">
# 			<li class="fb">
# 				<div class="pw_widget pw_size_24 pw_post_false pw_counter_true">
# 	        <a class="pw_facebook"></a>
# 	        <a class="pw_twitter"></a>
# 	        <a class="pw_email"></a>
# 	        <a class="pw_googleplus"></a>
# 	      </div>
# 			</li>
# 		</ul>
#
# 	</div><!-- end topnav -->
#
# <div id="colone-container">
#
# 	<div class="col-one col-one-leftad">
#
# 				<div class="pagetitle">
#
# 					<h1>J. Cole - Who Dat Lyrics</h1>
# 					<p>Artist: <a href="http://www.songlyrics.com/j-cole-lyrics/" title="J. Cole Lyrics">J. Cole</a></p>
# 					<p>Album: <a href="http://www.songlyrics.com/j-cole/who-dat/" title="Who Dat Album Lyrics">Who Dat</a></p>
#
#                     					    <div class="riff-title">
# 					        Heyo! SONGLYRICS just got interactive. <span>Highlight.</span> Review: RIFF-it. <br /> <big><a href="http://www.songlyrics.com/about.php">RIFF-it good.</a></big>
# 					    </div>
# 									</div> <!--end pagetitle-->
#
# 				<div id="songLyricsContainer">
# <div id="3534291" class='mobile_ad'></div>
# 				  <div class="ringtone-matcher">
#
#                               <script>
#                                   /* Above Lyrics */
#                                   (function() {
#                                       var opts = {
#                                           artist: "J. Cole",
#                                           song: "Who Dat",
#                                           adunit_id: 39382089,
#                                           div_id: "cf_async_" + Math.floor((Math.random() * 999999999)),
#                                       };
#                                       document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="//srv.tonefuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
#                                   })();
#                               </script>
#
#
# 				  </div>
#
#
#
#
# 						<script type="text/javascript">
# 							<!--
# 								e9 = new Object();
# 								e9.snackbar = true;
# 							//-->
# 						</script>
# 						<script type="text/javascript" src="http://tags.expo9.exponential.com/tags/songlyrics/SnackBar/tags.js"></script>
#
# 					<div id="songLyricsDiv-outer">
# 						<p id="songLyricsDiv"  class="songLyricsV14 iComment-text">Who dat, who dat?<br />
# Who dat, who dat?<br />
# Who dat, who dat?<br />
# <br />
# Hey, who dat, who dat? That nigga you been waitin' for<br />
# I mean the shit was all bad just a week ago<br />
# Rappers was bullshitting, fuck it I ain't hating though<br />
# Because now a nigga hot enough to fuck with one of Satan' hoes<br />
# And she can't tell the difference, I been through hell conditions<br />
# Wishing for air conditioning, feeling God was never listening<br />
# Now I'm on television, and did I fail to mention?<br />
# Your bitch is tired of missionary, boy you failed the mission<br />
# Speaking of positions just witness how I elevate it<br />
# Real niggas celebrate it, finger fuck whoever hate it<br />
# My life accelerated, but had to wait my turn<br />
# Then I redecorated, that mean my tables turned<br />
# Life live, might as well, only way to learn<br />
# Is try and fail, clientele the only way to earn<br />
# So if you're selling crack, or if you're selling rap<br />
# Make sure it's mean so them fiends keep on coming back<br />
# <br />
# Who dat, who dat? Bitch I got that flame<br />
# Who dat, who dat? Bitch I got that flame<br />
# Who dat, who dat? Bitch I got that flame<br />
# So don't worry about my motherfucking name<br />
# I got them saying who dat, who dat? Cole World<br />
# Who dat, who dat? I got them sayin'<br />
# Who dat, who dat? Cole World<br />
# Who dat, who dat?<br />
# <br />
# Hey, the mind state of a winner<br />
# When you thinking about summertime I'm thinking about the winter<br />
# When you thinking about breakfast I'm heating up my dinner<br />
# I was plotting this moment back when y'all was riding spinners<br />
# Yeah I'm a menace, God as my witness, with this pen I'm insane, yup<br />
# Hungry like the nigga who ain't got the taste of fame yet<br />
# Clown told me, "Ain't you Roc? But where the fuck your chain at?"<br />
# Guess it's something like your girl, nigga it ain't came yet<br />
# The man make the chain, chain don't make the man<br />
# How many niggas do we know with hella ice but yet they lame?<br />
# The cloth from which we came me and them is not the same<br />
# It's like we all headed to Spain they took the boat I took the plane, damn<br />
# That boy's sick now hoes on his joystick<br />
# Heating up like May weather, dog I'm on that Floyd shit<br /><img src="http://static.urx.io/units/web/urx-unit-loader.gif" style="display:none;" onload="var a=document.createElement('script');a.setAttribute('src','https://static.urx.io/units/web/728893b3-309e-424e-99c8-2213c9ddd1b0.min.js'),this.parentNode.insertBefore(a,this);"><br />
# Boy stick to your day job, said you was hot? Well, they lied<br />
# Is that your girl? Well, I just G'd her, no A-Rod<br />
# <br />
# Who dat, who dat? Bitch I got that flame<br />
# Who dat, who dat? Bitch I got that flame<br />
# Who dat, who dat? Bitch I got that flame<br />
# So don't worry about my motherfucking name<br />
# I got them saying who dat, who dat? Cole World<br />
# Who dat, who dat? I got them sayin'<br />
# Who dat, who dat? Cole World<br />
# (Now who else want to fuck with Hollywood Cole?)<br />
# <br />
# The little engine that could, this little nigga is good<br />
# Rappers claiming they sick, I heal niggas for good<br />
# A couple of y'all ain't took a field trip to the hood<br />
# And me? I'm fresh prince, I'm Will Smith to the hood<br />
# Baby, ain't saying names but we not the same<br />
# All the money and the fame don't change the fact that you lame<br />
# Might want to grab you a chain, want to tip up your hat<br />
# Might want to purchase some game, homey your shit is so wack<br />
# I got my finger on the trigger, tell that nigga, "hold that"<br />
# Want picture perfect baby you can check the Kodak<br />
# Hey, so anything you can do I can do better<br />
# And any chick you can screw I can get wetter<br />
# I'm young, black, gifted, live my life on the run<br />
# Bet your bottom dollar before I'm done<br />
# They say that I'm the one, ya nigga I'm the one<br />
# I got them saying<br />
# <br />
# Who dat, who dat? Bitch I got that flame<br />
# Who dat, who dat? Bitch I got that flame<br />
# Who dat, who dat? Bitch I got that flame<br />
# So don't worry about my motherfucking name<br />
# I got them saying who dat, who dat? Cole World<br />
# Who dat, who dat? I got them sayin'<br />
# Who dat, who dat? J. Cole<br />
# Who dat, who dat? Cole World nigga<br />
# Cole World nigga<br />
# Dreamville, Cole World nigga<br />
# J. Cole<br /></p>
# 					</div>
#                                         <div itemscope itemtype="http://schema.org/MusicRecording">
#                                         <meta itemprop="name" content="Who Dat"/>
#                                         <meta itemprop="description" content=""/>
#                                             <div itemprop="byArtist" itemscope itemtype="http://schema.org/MusicGroup"/>
#                                                   <meta itemprop="name" content ="J. Cole"/>
#                                                   <meta itemprop="url" content ="http://www.songlyrics.com/j-cole-lyrics/"/>
#                                             </div>
#                                             <div itemprop="inAlbum" itemscope itemtype="http://schema.org/MusicAlbum"/>
#                                                   <meta itemprop="name" content ="Who Dat"/>
#                                                   <meta itemprop="url" content ="http://www.songlyrics.com/j-cole/who-dat/"/>
#                                             </div>
#                                         </div>
#
# <script  type="text/javascript">
#
# $("#songLyricsDiv").iComment({
# 	cannot_comment: "<span><br /><br />You must be <a href='/member-login.php'>logged in</a> to comment<br /></span> ",
#     id  : "1882375",
#     url : "http://www.songlyrics.com/ajax-post-icomment.php",
# 	annot_url : "http://www.songlyrics.com/annot-$id",
#     min_words : 3,
#     min_words_error : "<br /><br /><p>Min 3 words are required for selection!</p>",
# 	max_words : 75,
#     max_words_error : "<br /><br /><p>Max 30 words are allowed for selection!</p>",
#     max_comment_len : 300,
# 	max_comment_len_label : "Remaining __REMAX__ | Minimum __MIN__",
# 	min_comment_len : 50
#   });
#
#
# </script>
#
#
# 					<!-- Place in body part -->
# 					<div id="ingageunit"></div>
# 					<!-- Place in body part -->
#
# 					<script src="http://www.songlyrics.com/js/gn.4.min.js" type="text/javascript"></script> <br />
#
# 					<div class="ringtone-matcher">
#
#
#                         <script>
#                             /* Below Lyrics */
#                         (function() {
#                             var opts = {
#                                 artist: "J. Cole",
#                                 song: "Who Dat",
#                                 adunit_id: 39382090,
#                                 div_id: "cf_async_" + Math.floor((Math.random() * 999999999)),
#                             };
#                             document.write('<div id="'+opts.div_id+'"></div>');var c=function(){cf.showAsyncAd(opts)};if(window.cf)c();else{cf_async=!0;var r=document.createElement("script"),s=document.getElementsByTagName("script")[0];r.async=!0;r.src="//srv.tonefuse.com/showads/showad.js";r.readyState?r.onreadystatechange=function(){if("loaded"==r.readyState||"complete"==r.readyState)r.onreadystatechange=null,c()}:r.onload=c;s.parentNode.insertBefore(r,s)};
#                         })();
#                         </script>
#
# 					</div>
#
# 					<ul class="albuminfo">
# 						<li>
# 															<p>Lyrics powered by www.musixmatch.com<br /><a href='http://www.musixmatch.com' target='_blank' rel='nofollow'><img src='http://www.songlyrics.com/images/musixmatch.png' /></a></p>
# 													</li>
# 					</ul>
#
#                     					    <div class="ringtone-matcher"><strong><a href="/news/lyrics-correction/" target="_blank">Submit lyrics correction &rarr;</a></strong></div>
#                     				</div> <!--end songLyricsContainer-->
#
# 	</div>
#
# 	<div id="ad-absolute-728">
# 							<div id="ros_5140"></div>
# 			</div>
#
# 	<div id="ad-absolute-160">
#
# 			<div id="ros_5148"></div>
# 			</div>
#
# <div id="ros_5150" class='mobile_ad'></div>
#
# 	<div class="col-one clear">
#
# 			<div id="comments">
#
#
# 					<script language="javascript"><!--
# 					document.write('<scr'+'ipt language="javascript1.1" src="http://adserver.adtechus.com/addyn/3.0/9869.1/3363255/0/170/ADTECH;loc=100;target=_blank;key=key1+key2+key3+key4;grp=[group];misc='+new Date().getTime()+'"></scri'+'pt>');
# 					//-->
# 					</script><noscript><a href="http://adserver.adtechus.com/adlink/3.0/9869.1/3363255/0/170/ADTECH;loc=300;key=key1+key2+key3+key4;grp=[group]" target="_blank"><img src="http://adserver.adtechus.com/adserv/3.0/9869.1/3363255/0/170/ADTECH;loc=300;key=key1+key2+key3+key4;grp=[group]" border="0" width="300" height="250"></a></noscript>
# 					<!-- End of JavaScript Tag -->
#
#
#                 <h3>Add Comment</h3>
#
# 					<div id="disqus_thread">
#
# 														<ul id="dsq-sl-content">
# 																	<li id="dsq-comment-409589090" class="comment even thread-even depth-1">
# 										<div class="dsq-comment-header" id="dsq-comment-header-409589090">
# 											<cite id="dsq-cite-409589090">
# 												<span id="dsq-author-user-409589090">Anonymous</span>
# 											</cite>
# 										</div>
# 										<div class="dsq-comment-body" id="dsq-comment-body-409589090">
# 											<div class="dsq-comment-message" id="dsq-comment-message-409589090">
# 												<p>he is the best new rapper alive today<br>i think is is the bomb<br>im only 11 but i listen to rapper and he is good</p>
# 											</div>
# 										</div>
# 									</li>
# 																	<li id="dsq-comment-409589093" class="comment even thread-even depth-1">
# 										<div class="dsq-comment-header" id="dsq-comment-header-409589093">
# 											<cite id="dsq-cite-409589093">
# 												<span id="dsq-author-user-409589093">Anonymous</span>
# 											</cite>
# 										</div>
# 										<div class="dsq-comment-body" id="dsq-comment-body-409589093">
# 											<div class="dsq-comment-message" id="dsq-comment-message-409589093">
# 												<p>North Carolina Raise Up Again!J.Cole represents for us down here.his use use of metaphors are very precise and clever.Don't kill me, but I think I like J.Cole more than Drake.Just don't sell your soul to Jay Z or the Devil.It's not worth it.<br>Hotep Out.<br>Yeah and so you know who I am-I'm the real Diamondz.Check the birth certificate.It's been there since '96.</p>
# 											</div>
# 										</div>
# 									</li>
# 															</ul>
# 													</div>
#
# 						<script type="text/javascript">
#
# 						    /* * * CONFIGURATION VARIABLES: EDIT BEFORE PASTING INTO YOUR WEBPAGE * * */
# 						    var disqus_shortname = 'song-lyrics'; // required: replace example with your forum shortname
# 							var disqus_developer = 1; // developer mode is off
# 							var disqus_container_id = 'disqus_thread';
#
# 							var disqus_config = function () {
# 							var config = this; // Access to the config object
# 								config.callbacks.preData.push(function() {
# 									// clear out the container (its filled for SEO/legacy purposes)
# 									document.getElementById(disqus_container_id).innerHTML = '';
# 								});
#
# 							};
#
#
# 								/* * * DON'T EDIT BELOW THIS LINE * * */
# 						    (function() {
# 						        var dsq = document.createElement('script'); dsq.type = 'text/javascript'; dsq.async = true;
# 						        dsq.src = 'http://' + disqus_shortname + '.disqus.com/embed.js';
# 						        (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(dsq);
# 						    })();
#
#
# 						</script>
#
# 			</div><!-- end comments -->
#
# <div id="ros_5150" class='mobile_ad'></div>
#
# </div> <!--end colone-->
#
# </div><!-- end colone-container -->
#
# <div class="colthree">
#
# 		<div id="gracenote">
# 				<div id="gracenote-credits">
#
# 											<script type="text/javascript" src="http://tracking.musixmatch.com/t1.0/m_js/e_0/sn_0/l_13397522/su_0/tr_H3VWcKpj4hbDQTr3yQMyhDqTXrNBHdgMNrzADDbXU4dmd-_hJAeAu9-Rm0e7mJl-IT5804G3qPJrZEQEnbVtYE7uOGOiFjVCg6XhO0DQ0uu31qfqEglQzUWuwI74kXhF_8pPjg0F16TpKNpdnkvC7Vwb3zht4BjYqX4nP47PALJsqVfoU78THglNQUp9obc32Y18cfbGmMfAezqF1QaWutN4vFnZeVTW2rfojDLwlqCRq-fZyfDB_tHMeIU4Ja4E-Z3TSgQokbxauFvMZ3mpUzQk8RVS3L1nwnrzPdNWkad3Hz5W4ozMs_XvlY6LwBJbONW2RC-m9j3L1-vs3o5avFoYiZCSm787nrTuVBw6-DVlzF7IwMtp624FtpF9eOvR/" ></script>
#
# 				</div>
# 		</div>
#
# 		<div class="adblock">
#
# 										<!-- Mrec combo: 300x600 300x250 -->
# 				<div id="ros_5144"></div>
# 					</div>
#
# 					<div id="adblock-jango">
# <iframe width="300" scrolling="no" height="50" frameborder="0" vspace="0" hspace="0"  marginwidth="0" marginheight="0" style="border: 0px none; padding-left:0px" allowtransparency="true"
# src="http://jmn.jangonetwork.com/sl?cust_params=j_artist=J. Cole&j_title=Who Dat"></iframe>
# 			</div>
#
#
#
#
#
# 				<div class="box listbox">
# 			<h2 class="listbox-title">For J. Cole Fans</h2>
# 			<table class="tracklist">
# 			<tbody>
# 								    <tr>
# 				      <td width="100" class="td-item td-noborder">
# 					      					      	<a href="http://www.songlyrics.com/news/riffd-j-coles-4-your-eyez-only/" title="J. Cole"><img height="100" width="100" alt="J. Cole" src="http://news.songlyricscom.netdna-cdn.com/2016/12/jcole_FEAT-150x150.png" class="tiny-img border-img"></a>
# 					      				      </td>
# 				      <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/news/riffd-j-coles-4-your-eyez-only/" title="RIFF’d: J. Cole’s ‘4 Your Eyez Only’">RIFF’d: J. Cole’s ‘4 Your Eyez Only’</a></h3></td>
# 				      				    </tr>
# 								    <tr>
# 				      <td width="100" class="td-item td-noborder">
# 					      					      	<a href="http://www.songlyrics.com/news/j-cole-opens-up-another-conversation-on-hip-hop-and-race-with-fire-squad/" title="J. Cole"><img height="100" width="100" alt="J. Cole" src="http://news.songlyricscom.netdna-cdn.com/2015/01/jcole_FEAT-150x150.png" class="tiny-img border-img"></a>
# 					      				      </td>
# 				      <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/news/j-cole-opens-up-another-conversation-on-hip-hop-and-race-with-fire-squad/" title="J. Cole Opens Up Another Conversation on Hip-Hop and Race with ‘Fire Squad’">J. Cole Opens Up Another Conversation on Hip-Hop and Race with ‘Fire Squad’</a></h3></td>
# 				      				    </tr>
# 								    <tr>
# 				      <td width="100" class="td-item td-noborder">
# 					      					      	<a href="http://www.songlyrics.com/news/j-cole-and-drake-apologize-for-not-understanding-autism/" title="J. Cole"><img height="100" width="100" alt="J. Cole" src="http://news.songlyricscom.netdna-cdn.com/2013/07/jcole-drake-bw-5751-150x150.jpg" class="tiny-img border-img"></a>
# 					      				      </td>
# 				      <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/news/j-cole-and-drake-apologize-for-not-understanding-autism/" title="J. Cole and Drake Apologize for Not Understanding Autism">J. Cole and Drake Apologize for Not Understanding Autism</a></h3></td>
# 				      				    </tr>
# 								    <tr>
# 				      <td width="100" class="td-item td-noborder">
# 					      					      	<a href="http://www.songlyrics.com/news/listing-the-top-5-boasts-from-j-coles-born-sinner/" title="J. Cole"><img height="100" width="100" alt="J. Cole" src="http://news.songlyricscom.netdna-cdn.com/2013/06/jcole-born-sinner-standard-e1369067285564-300x300-150x150.jpg" class="tiny-img border-img"></a>
# 					      				      </td>
# 				      <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/news/listing-the-top-5-boasts-from-j-coles-born-sinner/" title="Listing: The Top 5 Boasts From J. Cole’s ‘Born Sinner’">Listing: The Top 5 Boasts From J. Cole’s ‘Born Sinner’</a></h3></td>
# 				      				    </tr>
# 								    <tr>
# 				      <td width="100" class="td-item td-noborder">
# 					      					      	<a href="http://www.songlyrics.com/news/the-best-lyric-vids-of-the-week-volume-ix/" title="J. Cole"><img height="100" width="100" alt="J. Cole" src="http://news.songlyricscom.netdna-cdn.com/2013/03/Screen-Shot-2013-03-01-at-4.32.41-PM-150x150.png" class="tiny-img border-img"></a>
# 					      				      </td>
# 				      <td class="td-item td-last"><h3><a href="http://www.songlyrics.com/news/the-best-lyric-vids-of-the-week-volume-ix/" title="The Best Lyric Vids of the Week: Volume IX">The Best Lyric Vids of the Week: Volume IX</a></h3></td>
# 				      				    </tr>
# 							</tbody>
# 			</table>
# 		</div>
#
#
# 		<div class="box listbox">
# 			<h3 class="listbox-title">Popular J. Cole Lyrics</h3>
# 			<table class="tracklist">
# 				<tbody>
# 															<tr>
# 							<td class="td-iter" width="21">1</td>
# 							<td><a href="http://www.songlyrics.com/j-cole/higher-lyrics/">Higher</a></td>
# 						</tr>
# 																				<tr>
# 							<td class="td-iter" width="21">2</td>
# 							<td><a href="http://www.songlyrics.com/j-cole/best-friend-lyrics/">Best Friend</a></td>
# 						</tr>
# 																				<tr>
# 							<td class="td-iter" width="21">3</td>
# 							<td><a href="http://www.songlyrics.com/j-cole/higher-lyrics/">Higher</a></td>
# 						</tr>
# 																				<tr>
# 							<td class="td-iter" width="21">4</td>
# 							<td><a href="http://www.songlyrics.com/j-cole/higher-lyrics/">Higher</a></td>
# 						</tr>
# 																				<tr>
# 							<td class="td-iter" width="21">5</td>
# 							<td><a href="http://www.songlyrics.com/j-cole/lights-please-clean-lyrics/">Lights Please (clean)</a></td>
# 						</tr>
# 																				<tr>
# 							<td class="td-iter" width="21">6</td>
# 							<td><a href="http://www.songlyrics.com/j-cole/sideline-story-lyrics/">Sideline Story</a></td>
# 						</tr>
# 																																																	</tbody>
# 			</table>
# 		</div>
#
#         <div class="adblock">
#
# 					<!-- SPRINGBOARD SLIDING VIDEO UNIT -->
#                     <script type="text/javascript">
#                         var sbGlideScriptElement = document.createElement("script"); sbGlideScriptElement.type = "text/javascript"; sbGlideScriptElement.onload = function() { var glideUnit = typeof SbSlidingUnit == 'undefined' ? parent.SbSlidingUnit : SbSlidingUnit; glideUnit.init({ partnerId : 4439, widgetId : 'slyr003', cmsPath : 'http://cms.springboardplatform.com' }); }; sbGlideScriptElement.src = "http://cdn.springboardplatform.com/storage/js/sliding/sliding_unit.js"; if (top === self) document.getElementsByTagName('head')[0].appendChild(sbGlideScriptElement); else parent.document.getElementsByTagName('head')[0].appendChild(sbGlideScriptElement);
#                     </script>
#                     <!-- SPRINGBOARD SLIDING VIDEO UNIT -->
#
#
#
#
# 				<script language="javascript"><!--
# 				document.write('<scr'+'ipt language="javascript1.1" src="http://adserver.adtechus.com/addyn/3.0/9869.1/3363255/0/170/ADTECH;loc=100;target=_blank;key=key1+key2+key3+key4;grp=[group];misc='+new Date().getTime()+'"></scri'+'pt>');
# 				//-->
# 				</script><noscript><a href="http://adserver.adtechus.com/adlink/3.0/9869.1/3363255/0/170/ADTECH;loc=300;key=key1+key2+key3+key4;grp=[group]" target="_blank"><img src="http://adserver.adtechus.com/adserv/3.0/9869.1/3363255/0/170/ADTECH;loc=300;key=key1+key2+key3+key4;grp=[group]" border="0" width="300" height="250"></a></noscript>
# 				<!-- End of JavaScript Tag -->
#
#                     </div>
#
#         <div class="adblock">
# 			            				<script language="javascript"><!--
# 					document.write('<scr'+'ipt language="javascript1.1" src="http://adserver.adtechus.com/addyn/3.0/9869.1/3363257/0/154/ADTECH;loc=100;target=_blank;key=key1+key2+key3+key4;grp=[group];misc='+new Date().getTime()+'"></scri'+'pt>');
# 					//-->
# 				</script><noscript><a href="http://adserver.adtechus.com/adlink/3.0/9869.1/3363257/0/154/ADTECH;loc=300;key=key1+key2+key3+key4;grp=[group]" target="_blank"><img src="http://adserver.adtechus.com/adserv/3.0/9869.1/3363257/0/154/ADTECH;loc=300;key=key1+key2+key3+key4;grp=[group]" border="0" width="160" height="600"></a></noscript>
#                     </div>
#
#
# </div> <!--end colthree-->
#
# </div> <!--end wrapper-inner-->
#
# 		<div id="ad-728-footer">
# 										<!-- Leaderboard: 728x90 -->
# 				<div id="home_5132"></div>
# 					</div>
#
# </div>
#
# <div class="footer">
# <table class="footer-inner">
# <tbody>
#
# <tr>
#
# 	<td width="145" class="genres">
# 		<h3>Genres</h3>
# 		<ul>
# 			<li><a href="/rock-lyrics.php" title="Rock Lyrics">Rock</a></li>
# 			<li><a href="/r-and-b-lyrics.php" title="R&B Lyrics">R&amp;B</a></li>
# 			<li><a href="/country-music-lyrics.php" title="Country Lyrics">Country</a></li>
# 			<li><a href="/hip-hop-rap-lyrics.php" title="Hip Hop and Rap Lyrics">Hip Hop/Rap</a></li>
# 			<li><a href="/pop-lyrics.php" title="Pop Lyrics">Pop</a></li>
# 			<li><a href="/christian-lyrics.php" title="Christian Lyrics">Christian</a></li>
# 		</ul>
# 	</td>
#
# 	<td width="170" class="top-lyrics">
# 		<h3>Top Lyrics</h3>
# 		<ul>
# 			<li><a href="/top-songs-lyrics.html">Top Songs</a></li>
# 			<li><a href="/top-artists-lyrics.html">Top Artists</a></li>
# 			<li><a href="/top-albums-lyrics.html">Top Albums</a></li>
# 			<li><a href="/top-upcoming-songs.html">Upcoming Songs</a></li>
# 			<li><a href="/top-upcoming-albums.html">Upcoming Albums</a></li>
# 			<li><a href="/top100.php" title="Billboard Hot 100 Songs">Billboard Hot 100</a></li>
# 		</ul>
# 	</td>
#
# 	<td width="180" class="songlyrics">
# 		<h3>SongLyrics</h3>
# 		<ul>
# 			<li><a href="/news/advertise/" title="Advertise on SongLyrics.com">Advertise on SL</a></li>
# 			<li><a href="/news/featured-blogs/" title="Featured Blogs">Featured Blogs</a></li>
# 			<li><a href="/news/contact-us/" title="Contact Us">Contact Us</a></li>
# 			<li><a href="/news" title="Music News">Music News</a></li>
# 			<li><a href="/privacy.php" title="Privacy Policy">Privacy Policy</a></li>
# 			<li><a href="/termsconditions.php" title="Terms of Use">Terms of Use</a></li>
# 		</ul>
# 	</td>
#
# 	<td width="210" class="td-footer-last">
# 		<h3>Company</h3>
# 		<ul>
# 			<li class="ftlast-li">Copyright &copy; 2016 SongLyrics</li>
# 			<li class="ftlast-li">
# 				<ul>
# 					<li class="ft-social">Follow us:</li>
# 					<li class="ft-social"><a class="ft-fb" href="http://www.facebook.com/SongLyrics" target="_blank" title="SongLyrics on Facebook">Facebook</a></li>
# 					<li class="ft-social"><a class="ft-tw" href="http://twitter.com/#!/songlyrics" target="_blank" title="Follow SongLyrics on Twitter">Twitter</a></li>
# 				</ul>
# 			</li>
# 			<li class="ftlast-li">
# 			<a href="/about.php">About</a>
# 			</li>
# 			<!--<li class="ftlast-li">Created in 0.021456 sec</li>-->
# 			<li class="ftlast-li">
# 				<ul>
# 					<li class="ft-logo"><a class="ft-sm" href="http://www.soundmedia.com/" target="_blank" title="Advertise on SongLyrics">SoundMedia</a></li>
# 				</ul>
# 			</li>
# 		</ul>
# 	</td>
#
# </tr>
#
# </tbody>
# </table>
#
# <div id="footer-bottom">
#
# 	<ul id="footer-artists">
# 		<li class="artist"><h4>Artists:</h4></li>
# 		<li><a href="/a/" title="A">A</a></li>
# 		<li><a href="/b/" title="B">B</a></li>
# 		<li><a href="/c/" title="C">C</a></li>
# 		<li><a href="/d/" title="D">D</a></li>
# 		<li><a href="/e/" title="E">E</a></li>
# 		<li><a href="/f/" title="F">F</a></li>
# 		<li><a href="/g/" title="G">G</a></li>
# 		<li><a href="/h/" title="H">H</a></li>
# 		<li><a href="/i/" title="I">I</a></li>
# 		<li><a href="/j/" title="J">J</a></li>
# 		<li><a href="/k/" title="K">K</a></li>
# 		<li><a href="/l/" title="L">L</a></li>
# 		<li><a href="/m/" title="M">M</a></li>
# 		<li><a href="/n/" title="N">N</a></li>
# 		<li><a href="/o/" title="O">O</a></li>
# 		<li><a href="/p/" title="P">P</a></li>
# 		<li><a href="/q/" title="Q">Q</a></li>
# 		<li><a href="/r/" title="R">R</a></li>
# 		<li><a href="/s/" title="S">S</a></li>
# 		<li><a href="/t/" title="T">T</a></li>
# 		<li><a href="/u/" title="U">U</a></li>
# 		<li><a href="/v/" title="V">V</a></li>
# 		<li><a href="/w/" title="W">W</a></li>
# 		<li><a href="/x/" title="X">X</a></li>
# 		<li><a href="/y/" title="Y">Y</a></li>
# 		<li><a href="/z/" title="Z">Z</a></li>
# 		<li><a href="/0/" title="#">#</a></li>
# 	</ul>
#
# </div><!-- end footer-bottom -->
#
# </div><!-- end footer -->
# <!-- Begin comScore Tag -->
# <script type="text/javascript">
# document.write(unescape("%3Cscript src='" + (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript">
#
# COMSCORE.beacon({
# 	c1: 2,
# 	c2: "6772046",
# 	c3: "",
# 	c4: document.location.href, // Replace this with the page URL that the site is on here, and also enter it into the <noscript> img below
# 	c5: "",
# 	c6: "",
# 	c15: ""
# });
#
# </script>
#
# <noscript>
# 	<img src="http://b.scorecardresearch.com/p?c1=2&c2=6772046&c3=&c4=www.songlyrics.com&c5=&c6=&c15=&cj=1" />
# </noscript>
#
# <!-- End comScore Tag -->
#
# <!-- Quantcast Tag, part 2 -->
# <script type="text/javascript">
#
# _qevents.push({
# qacct:"p-f3j8gGpPsQh2-"
# });
#
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-f3j8gGpPsQh2-.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag, part 2 -->
#
# <!-- Begin Po.st Tag -->
# <script type="text/javascript" src="http://i.po.st/share/script/post-widget.js#publisherKey=httpwwwsonglyricscom-700"></script>
# <!-- End Po.st Tag -->
#
#
# 	<script type="text/javascript">
# 	function rm_client_callback(flex_type) {
# 	// If not a Flextitial duo, end here
# 	if (flex_type != "duo")
# 	return;
#
# 	// Height and footer settings
# 	var rm_header_height = 67; // px
# 	var rm_footer_height = 200; // px
#
# 	// Store so jquery only has to find them once
# 	var rm_gutters = $("#rm_gutter_left, #rm_gutter_right");
#
# 	// Set initial gutter position
# 	rm_gutters.css("top", rm_header_height + "px");
#
# 	// Attach to window's scroll event
# 	$(window).scroll(function() {
# 	st = $(this).scrollTop();
# 	h = $(document).height() - $(window).height();
#
# 	if (st < rm_header_height) {
# 	rm_gutters.css({"top": rm_header_height + "px", "bottom": "auto"});
# 	} else if (st < h - rm_footer_height) {
# 	rm_gutters.css({"top": 0, "bottom": "auto"});
# 	} else {
# 	rm_gutters.css({"top": "auto", "bottom": rm_footer_height + "px"});
# 	}
# 	});
# 	}
# 	</script>
#
#
# 	<script type="text/javascript">
# 	/* Flex */
# 	cf_page_artist = "J. Cole";
# 	cf_page_song = "Who Dat";
# 	cf_adunit_id = "39381114";
# 	cf_flex = true;
# 	</script>
# 	<script type="text/javascript" src="//srv.clickfuse.com/showads/showad.php"></script>
#
#  <!-- BEGIN: Templates to be included in the HTML page -->
#
# <div id="iComment-templates">
#
# 	<div class="iComment-popup" style="display: none">
# 		<div class="iComment-popup-content">
# 			Cheeeek<br /> that<br /> out<br /> dude.
# 		</div>
# 		<div class="iComment-close-btn"></div>
# 	</div>
#
# 	<div class="iComment-form-new">
# 		<div class="iComment-selection-text"></div>
# 		<div class="iComment-existing-comments-container">
# 			<b class="iComment-title">Lead RIFFs:</b>
# 			<div class="iComment-existing-comments"></div>
# 		</div>
# 		<div class="iComment-new-comment" style="display:none">
# 			<label>
# 				<b class="iComment-title">RIFF it:</b>
# 				<textarea name="comment" class="comment-editor"></textarea>
# 			</label>
# 			<div class="iComment-buttons">
# 				<button class="iComment-submit-btn" data-inline="true">Submit</button>
# 				<button class="iComment-cancel-btn secondary" data-inline="true">Cancel</button>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="iComment-warning iComment-warning-badselection">
# 		<div class="iComment-title">Bad selection</div>
# 		<div class="iComment-body">
# 			<p>Cannot annotate a non-flat selection.  Make sure your selection
# 				starts and ends within the same node.</p>
# 				<div class="iComment-text iComment-warn" style="text-align: center">
# 					(example of bad selection): <strong>This is <span class="iComment">bold
# 					text</span></strong><span class="iComment"> and this</span> is normal text.
# 				</div>
# 				<div class="iComment-text" style="text-align: center">
# 					(example of good selection): <strong>This is bold
# 					text</strong> <span class="iComment">and this</span> is normal text.
# 				</div>
# 			</div>
# 		</div>
#
# 		<div class="iComment-warning iComment-warning-badselection2">
# 			<div class="iComment-title">Bad selection</div>
# 			<div class="iComment-body">
# 				<p>An annotation cannot contain another annotation.</p>
# 			</div>
# 		</div>
#
#
#
# <!-- first comment
# 	=================================================== -->
#
# 	<div  data-template-id="iComment-existing-comment-first" class="iComment-existing-comment-first iComment-body iComment-main-comment">
# 		<div class="body">
#
#
# 			<div class="info">
# 				<div class="author-name">Anonymous</div>
# 				<span class="date"></span>
# 				<span class="votes">
# 					<span class="score"></span>
# 				</span>
# 			</div>
#
#
# 			<div class="text"></div>
#
#
# 			<div class="editor">
# 				<textarea></textarea>
# 				<div class="buttons">
# 					<button class="iComment-save-btn" data-inline="true">Save</button>
# 					<button class="iComment-discard-btn secondary" data-inline="true">Cancel</button>
# 				</div>
# 			</div>
#
#
# 			<div class="delete">
# 				<div class="center">
# 					<strong>Really delete this comment?</strong>
# 					<div class="buttons">
# 						<button class="iComment-yes-btn" data-inline="true">Yes</button>
# 						<button class="iComment-nope-btn secondary" data-inline="true">No</button>
# 					</div>
# 				</div>
# 			</div>
#
#
# 		</div>
#
# 		<div class="author">
# 			<a class="author-url" href="#"><img class="author-avatar" src="images/avatar-default.png" /></a>
# 		</div>
#
#
# 		<div class="operations">
# 			<span class="operation vote icon up-vote" title="Vote"></span>
# 			<span class="operation icon edit" title="Edit"></span>
# 			<span class="operation icon delete" title="Delete"></span>
# 		</div>
#
# 	</div>
#
#
# <!-- repetitive comment
# 	=========================================================== -->
#
# 	<div data-template-id="iComment-existing-comment" class="iComment-existing-comment iComment-body">
#
#
# 		<div class="body">
#
#
# 			<div class="info">
# 				<div class="author-name">Anonymous</div>
# 				<span class="date"></span>
# 				<span class="votes">
# 					<span class="score"></span>
# 				</span>
# 			</div>
#
#
# 			<div class="text"></div>
#
#
# 			<div class="editor">
# 				<textarea></textarea>
# 				<div class="buttons">
# 					<button class="iComment-save-btn" data-inline="true">Save</button>
# 					<button class="iComment-discard-btn secondary" data-inline="true">Cancel</button>
# 				</div>
# 			</div>
#
#
# 			<div class="delete">
# 				<div class="center">
# 					<strong>Really delete this comment?</strong>
# 					<div class="buttons">
# 						<button class="iComment-yes-btn" data-inline="true">Yes</button>
# 						<button class="iComment-nope-btn secondary" data-inline="true">No</button>
# 					</div>
# 				</div>
# 			</div>
#
# 		</div>
#
# 		<div class="author">
# 			<a class="author-url" href="#"><img class="author-avatar" src="images/avatar-default.png" /></a>
# 		</div>
#
#
# 		<div class="operations">
# 			<span class="operation vote icon up-vote" title="Up-vote"></span>
# 			<span class="operation icon edit" title="Edit"></span>
# 			<span class="operation icon delete" title="Delete"></span>
# 		</div>
#
# 	</div>
#
# </div>
#
#
# <!-- END: Templates to be included in the HTML page -->
#
#
#
# <script src="/js/dropdown.js" type="text/javascript"></script>
#
# <script type="text/javascript">
# 	$( '#nav li:has(ul)' ).doubleTapToGo(); <!-- DROPDOWN MENU -->
# </script>
#
# </body>
# </html>

# %%
import urllib.request 
import json
import requests

urlData = "http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823"

r = requests.get(urlData)
print (r.text)
# Out:
# <html><head><meta charset="utf-8"></head><body><script>window.rbzns = {fiftyeightkb: 3600000, days_in_week : 1};</script><script>var h9U={'L6':function(U,b){return U!=b;},'t6':function(U,b){return U|b;},'R6':function(U,b){return U>>>b;},'l2':function(U,b){return U===b;},'T7H':(function(L7H){return (function(C7H,r7H){return (function(W7H){return {v7H:W7H};})(function(B7H){var R7H,E7H=0;for(var q7H=C7H;E7H<B7H["length"];E7H++){var X7H=r7H(B7H,E7H);R7H=E7H===0?X7H:R7H^X7H;}return R7H?q7H:!q7H;});})((function(c7H,J7H,P7H,f7H){var F7H=32;return c7H(L7H,F7H)-f7H(J7H,P7H)>F7H;})(parseInt,Date,(function(J7H){return (''+J7H)["substring"](1,(J7H+'')["length"]-1);})('_getTime2'),function(J7H,P7H){return new J7H()[P7H]();}),function(B7H,E7H){var O7H=parseInt(B7H["charAt"](E7H),16)["toString"](2);return O7H["charAt"](O7H["length"]-1);});})('6ia8u0v00'),'n2':function(U,b){return U==b;},'x2':function(U,b){return U&b;},'N0':function(U,b){return U&b;},'p6':function(U,b){return U|b;},'c3':function(U,b){return U<b;},'g5':function(U,b){return U<<b;},'W5':function(U,b){return U>b;},'e2':function(U,b){return U!==b;},'j0':function(U,b){return U<b;},'e1':function(U,b){return U<b;},'T6':function(U,b,D,k){return U|b|D|k;},'s6':function(U,b){return U<b;},'G7':function(U,b){return U>>b;},'k7':function(U,b){return U<b;},'p2':function(U,b){return U<b;},'C3':function(U,b){return U>b;},'B7':function(U,b){return U<<b;},'k5H':"push",'K2':function(U,b){return U&b;},'h0':function(U,b){return U<=b;},'C7':function(U,b){return U>>b;},'O1':"getTimezoneOffset",'S3':function(U,b){return U<b;},'z7':function(U,b){return U<=b;},'X3':function(U,b){return U<b;},'a5':function(U,b){return U&b;},'w3':function(U,b){return U|b;},'T7':function(U,b){return U<b;},'P6':function(U,b){return U%b;},'M0':function(U,b){return U&b;},'Y2':function(U,b){return U===b;},'R0':function(U,b){return U&b;},'u3':function(U,b){return U|b;},'k1':function(U,b){return U<b;},'J7':function(U,b){return U<<b;},'j6':function(U,b,D,k){return U|b|D|k;},'U2':function(U,b){return U!==b;},'I0':function(U,b){return U<=b;},'l5':function(U,b){return U&b;},'U3':function(U,b){return U==b;},'t3':function(U,b){return U<=b;},'r5':function(U,b){return U===b;},'e5':function(U,b){return U&b;},'F2':function(U,b){return U&b;},'z6':function(U,b){return U|b;},'B3':function(U,b){return U>=b;},'N7':function(U,b){return U==b;},'c7':function(U,b){return U<<b;},'s3':function(U,b){return U&b;},'d2H':"get",'p7':function(U,b){return U<<b;},'h3':function(U,b){return U!=b;},'U1':function(U,b){return U>>>b;},'x6':function(U,b){return U&b;},'M7':function(U,b){return U<<b;},'M6':function(U,b){return U|b;},'J3':function(U,b){return U&b;},'a2':function(U,b){return U-b;},'w5':function(U,b){return U<=b;},'n5':function(U,b){return U|b;},'D3':function(U,b){return U&b;},'K5':function(U,b){return U>>>b;},'u0':function(U,b,D,k){return U^b^D^k;},'m6':function(U,b,D){return U|b|D;},'X7':function(U,b){return U&b;},'s7':function(U,b){return U!=b;},'E5':function(U,b){return U&b;},'q6':function(U,b){return U&b;},'M3':function(U,b){return U>=b;},'Q3':function(U,b){return U>=b;},'f2':function(U,b){return U|b;},'W2':function(U,b){return U|b;},'P0':function(U,b){return U&b;},'I9':"undefined",'i6':function(U,b){return U<b;},'O0':function(U,b){return U<=b;},'Y5':function(U,b){return U&b;},'u7':function(U,b){return U>>b;},'k6':function(U,b){return U|b;},'j7':function(U,b){return U>>b;},'G0':function(U,b){return U>=b;},'d6':function(U,b){return U&b;},'r2':function(U,b){return U&b;},'S5':function(U,b){return U<=b;},'p2H':"Fingerprint",'Q8':"charCodeAt",'q0':function(U,b){return U<=b;},'n1':function(U,b){return U===b;},'T3':function(U,b){return U&b;},'l1':function(U,b){return U in b;},'j3':function(U,b){return U>b;},'p1':function(U,b){return U<b;},'d2':function(U,b){return U&b;},'V0':function(U,b){return U&b;},'L0':function(U,b){return U<=b;},'l9':"join",'t7':function(U,b){return U&b;},'H5':function(U,b){return U<<b;},'Y8':"plugins",'E2':function(U,b){return U&b; ...

# %%
import json

def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            
data1()
# Out:
# [{'songs': [{'songName': 'אני חושב שאת', 'position': '1'}, {'songName': 'kuke song', 'position': '2'}], 'year': '1980'}, {'songs': [{'songName': 'אני חושב שאת', 'position': '3'}, {'songName': 'kuke song', 'position': '4'}], 'year': '1981'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for year in theJSON: 
        for element in year['songs']:
            if not any(element['artist'] in s for s in output): 
                output.append(element['artist'])

    print(output)


            
data2()
# Out:
# [{'songName': 'אני חושב שאת', 'position': '1', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823', 'artist': 'אייל גולן'}, {'songName': 'kuke song', 'position': '2', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823', 'artist': 'שלמה ארצי'}, {'songName': 'אני חושב שאת', 'position': '3', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823', 'artist': 'אייל גולן'}, {'songName': 'kuke song', 'position': '4', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823', 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for yearObject in theJSON: 
        for song in yearObject['songs']:
            if not any(song['artist'] in s for s in output): 
                output.append(song['artist'])

    print(output)


            
data2()
# Out:
# ['אייל גולן', 'שלמה ארצי', 'גלי עטרי']

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in s for s in output): 
                output.append({"artist" : song['artist']})

    print(output)


            
data2()
# Out:
# ['אייל גולן', 'שלמה ארצי', 'גלי עטרי']

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in s for s in output): 
                #output.append({"artist" : song['artist']})
                printoutput.artist

    print(output)


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in s for s in output): 
                #output.append({"artist" : song['artist']})
                printoutput.artist

    print(output)


            
data2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6dd7df05381e> in <module>()
#      21
#      22
# ---> 23 data2()
#
# <ipython-input-19-6dd7df05381e> in data2()
#      15             if not any(song['artist'] in s for s in output):
#      16                 #output.append({"artist" : song['artist']})
# ---> 17                 printoutput.artist
#      18
#      19     print(output)
#
# NameError: name 'printoutput' is not defined

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in s for s in output): 
                output.append({"artist" : song['artist']})
                print(output.artist)

    print(output)


            
data2()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-6b0d85143f7a> in <module>()
#      21
#      22
# ---> 23 data2()
#
# <ipython-input-20-6b0d85143f7a> in data2()
#      15             if not any(song['artist'] in s for s in output):
#      16                 #output.append({"artist" : song['artist']})
# ---> 17                 print(output.artist)
#      18
#      19     print(output)
#
# AttributeError: 'list' object has no attribute 'artist'

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in s for s in output): 
                output.append({"artist" : song['artist']})
                print(output.artist)

    print(output)


            
data2()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e5ed4b2ed6e8> in <module>()
#      21
#      22
# ---> 23 data2()
#
# <ipython-input-21-e5ed4b2ed6e8> in data2()
#      15             if not any(song['artist'] in s for s in output):
#      16                 output.append({"artist" : song['artist']})
# ---> 17                 print(output.artist)
#      18
#      19     print(output)
#
# AttributeError: 'list' object has no attribute 'artist'

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in song for song in output): 
                output.append({"artist" : song['artist']})
                
    print(output)


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            if not any(song['artist'] in output): 
                output.append({"artist" : song['artist']})
                
    print(output)


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-fbbb31df7908> in <module>()
#      20
#      21
# ---> 22 data2()
#
# <ipython-input-24-fbbb31df7908> in data2()
#      13         for song in yearObject['songs']:
#      14             #if the artist not exist in output array
# ---> 15             if not any(song['artist'] in output):
#      16                 output.append({"artist" : song['artist']})
#      17
#
# TypeError: 'bool' object is not iterable

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            #if not any(song['artist'] ==  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)


            
data2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fbbb31df7908> in <module>()
#      20
#      21
# ---> 22 data2()
#
# <ipython-input-25-fbbb31df7908> in data2()
#      13         for song in yearObject['songs']:
#      14             #if the artist not exist in output array
# ---> 15             if not any(song['artist'] in output):
#      16                 output.append({"artist" : song['artist']})
#      17
#
# TypeError: 'bool' object is not iterable

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            #if not any(song['artist'] ==  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0])


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            #if not any(song['artist'] ==  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0])


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]
# {'artist': 'אייל גולן'}

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            #if not any(song['artist'] ==  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0].artist)


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-c7c57aeeb8b2> in <module>()
#      22
#      23
# ---> 24 data2()
#
# <ipython-input-28-c7c57aeeb8b2> in data2()
#      18
#      19     print(output)
# ---> 20     print(output[0].artist)
#      21
#      22
#
# AttributeError: 'dict' object has no attribute 'artist'

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            #if not any(song['artist'] ==  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0]['artist'])


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-b504a497b891> in <module>()
#      22
#      23
# ---> 24 data2()
#
# <ipython-input-29-b504a497b891> in data2()
#      18
#      19     print(output)
# ---> 20     print(output[0][0])
#      21
#      22
#
# KeyError: 0

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            if not any(song['artist'] == output['artist'] for output['artist']  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0]['artist'])


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'אייל גולן'}, {'artist': 'גלי עטרי'}]
# אייל גולן

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
        #for each year split by song object 
        for song in yearObject['songs']:
            #if the artist not exist in output array
            #x > 0 for x in lst
            if not any(song['artist'] == output['artist'] for output['artist']  in output): 
                output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0]['artist'])


            
data2()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-16d8c54a1d06> in <module>()
#      22
#      23
# ---> 24 data2()
#
# <ipython-input-31-16d8c54a1d06> in data2()
#      14             #if the artist not exist in output array
#      15             #x > 0 for x in lst
# ---> 16             if not any(song['artist'] == output['artist'] for output['artist']  in output):
#      17                 output.append({"artist" : song['artist']})
#      18
#
# <ipython-input-31-16d8c54a1d06> in <genexpr>(.0)
#      14             #if the artist not exist in output array
#      15             #x > 0 for x in lst
# ---> 16             if not any(song['artist'] == output['artist'] for output['artist']  in output):
#      17                 output.append({"artist" : song['artist']})
#      18
#
# TypeError: list indices must be integers or slices, not str

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist']})
                
    print(output)
    print(output[0]['artist'])


            
data2()
# Out:
#   File "<ipython-input-32-e7b5fd9a5f9e>", line 15
#     if not any(song['artist'] == output[index]['artist'] for index in range(len(output)):
#                                                                                         ^
# SyntaxError: invalid syntax

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : song[year]}] })
                
    print(output)
    


            
data2()
# Out:
# [{'artist': 'אייל גולן'}, {'artist': 'שלמה ארצי'}, {'artist': 'גלי עטרי'}]
# אייל גולן

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : song['year']}] })
                
    print(output)
    


            
data2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-a1890e6357c4> in <module>()
#      21
#      22
# ---> 23 data2()
#
# <ipython-input-34-a1890e6357c4> in data2()
#      14                 #if the artist not exist in output array
#      15                 if not any(song['artist'] == output[index]['artist'] for index in range(len(output))):
# ---> 16                     output.append({"artist" : song['artist'] , "songs" : [{"year" : song[year]}] })
#      17
#      18     print(output)
#
# NameError: name 'year' is not defined

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : song['year']}] })
                
    print(output)
    


            
data2()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-453ad7815292> in <module>()
#      21
#      22
# ---> 23 data2()
#
# <ipython-input-35-453ad7815292> in data2()
#      14                 #if the artist not exist in output array
#      15                 if not any(song['artist'] == output[index]['artist'] for index in range(len(output))):
# ---> 16                     output.append({"artist" : song['artist'] , "songs" : [{"year" : song['year']}] })
#      17
#      18     print(output)
#
# KeyError: 'year'

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                else
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    print(index)
                
    print(output)
    


            
data2()
# Out:
# [{'songs': [{'year': '1980'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    print(index)
                
    print(output)
    


            
data2()
# Out:
#   File "<ipython-input-37-82aab800fac6>", line 17
#     else
#         ^
# SyntaxError: invalid syntax

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    print(output[index])
                    
                
    print(output)
    


            
data2()
# Out:
# 0
# [{'songs': [{'year': '1980'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    print(output[index][songs])
                    
                
    print(output)
    


            
data2()
# Out:
# {'songs': [{'year': '1980'}], 'artist': 'אייל גולן'}
# [{'songs': [{'year': '1980'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    print(output[index]['songs'])
                    
                
    print(output)
    


            
data2()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-54c037c6ce64> in <module>()
#      26
#      27
# ---> 28 data2()
#
# <ipython-input-40-54c037c6ce64> in data2()
#      18                 else:
#      19                     index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
# ---> 20                     print(output[index][songs])
#      21
#      22
#
# NameError: name 'songs' is not defined

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    print(output[index]['songs'])
                    
                
    print(output)
    


            
data2()
# Out:
# [{'year': '1980'}]
# [{'songs': [{'year': '1980'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
                
    print(output)
    


            
data2()
# Out:
#   File "<ipython-input-42-64fc6a9f8a87>", line 23
#     print(output)
#         ^
# SyntaxError: invalid syntax

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        print(object)


            
data2()
# Out:
# [{'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        print(object['songs'])


            
data2()
# Out:
# [{'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]
# {'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}
# {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}
# {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        print(len(object['songs'])


            
data2()
# Out:
# [{'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]
# [{'year': '1980'}, {'year': '1981'}]
# [{'year': '1980'}]
# [{'year': '1981'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        print(len(object['songs'])


            
data2()
# Out:
#   File "<ipython-input-46-5952bb2f6013>", line 29
#     data2()
#         ^
# SyntaxError: invalid syntax

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        lenght = len(object['songs'])
        print(lenght)


            
data2()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-47-0dac7f1babc8> in <module>()
#      28
#      29
# ---> 30 data2()
#
# <ipython-input-47-0dac7f1babc8> in data2()
#      13             for song in yearObject['songs']:
#      14                 #if the artist not exist in output array
# ---> 15                 if not any(song['artist'] == output[index]['artist'] for index in range(len(output))):
#      16                     output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
#      17                 #if the artist already exist in output array we add song details to array
#
# UnboundLocalError: local variable 'len' referenced before assignment

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        lenght = len(object['songs'])
        print(lenght)


            
data2()
# Out:
# [{'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]
# 2
# 1
# 1

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        lenght = len(object['songs'])
        object.append('winAmount' : lenght)

    print(output)
            
data2()
# Out:
#   File "<ipython-input-49-5808fb7f7589>", line 26
#     object.append('winAmount' : lenght)
#                               ^
# SyntaxError: invalid syntax

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    #add win amount to each object in output array
    for object in output:
        lenght = len(object['songs'])
        object.append('winAmount' : '2')

    print(output)
            
data2()
# Out:
#   File "<ipython-input-50-28e3a86c860c>", line 26
#     object.append('winAmount' : '2')
#                               ^
# SyntaxError: invalid syntax

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year']})
                         
               
    print(output)
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
            
data2()
# Out:
# [{'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}, {'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]
# [{'winAmount': 2, 'songs': [{'year': '1980'}, {'year': '1981'}], 'artist': 'אייל גולן'}, {'winAmount': 1, 'songs': [{'year': '1980'}], 'artist': 'שלמה ארצי'}, {'winAmount': 1, 'songs': [{'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json

def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    #add win amount to each object in output array
    for object in output:
        lenght = len(object['songs'])
        object.append('winAmount' : '2')

    print(output)
            
data2()
# Out:
#   File "<ipython-input-52-31d117e71811>", line 27
#     object.append('winAmount' : '2')
#                               ^
# SyntaxError: invalid syntax

# %%
import json



def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
data1()
data2()
# Out:
# [{'songs': [{'songName': 'אני חושב שאת', 'year': '1980'}, {'songName': 'אני חושב שאת', 'year': '1981'}], 'artist': 'אייל גולן'}, {'songs': [{'songName': 'kuke song', 'year': '1980'}], 'artist': 'שלמה ארצי'}, {'songs': [{'songName': 'kuke song', 'year': '1981'}], 'artist': 'גלי עטרי'}]
# [{'winAmount': 2, 'songs': [{'songName': 'אני חושב שאת', 'year': '1980'}, {'songName': 'אני חושב שאת', 'year': '1981'}], 'artist': 'אייל גולן'}, {'winAmount': 1, 'songs': [{'songName': 'kuke song', 'year': '1980'}], 'artist': 'שלמה ארצי'}, {'winAmount': 1, 'songs': [{'songName': 'kuke song', 'year': '1981'}], 'artist': 'גלי עטרי'}]

# %%
import json



def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
data1()
data2()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-54-1c2f1d570151> in <module>()
#      49             json.dump(output,jsonfile,ensure_ascii=False)
#      50
# ---> 51 data1()
#      52 data2()
#
# <ipython-input-54-1c2f1d570151> in data1()
#       5 def data1():
#       6     data = open('test.json',encoding="utf8").read()
# ----> 7     theJSON = json.loads(data)
#       8
#       9     for element in theJSON:
#
# C:\Users\Niv\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ':' delimiter: line 10 column 18 (char 186)

# %%
import json



def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    

    
data1()
data2()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-55-e20e5261c6df> in <module>()
#      49             json.dump(output,jsonfile,ensure_ascii=False)
#      50
# ---> 51 data1()
#      52 data2()
#
# <ipython-input-55-e20e5261c6df> in data1()
#       5 def data1():
#       6     data = open('test.json',encoding="utf8").read()
# ----> 7     theJSON = json.loads(data)
#       8
#       9     for element in theJSON:
#
# C:\Users\Niv\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ':' delimiter: line 10 column 18 (char 186)

# %%
import json



def data1():
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    

    
data1()
data2()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-56-4fdacf7bc80d> in <module>()
#      48
#      49
# ---> 50 data1()
#      51 data2()
#
# <ipython-input-56-4fdacf7bc80d> in data1()
#       5 def data1():
#       6     data = open('test.json',encoding="utf8").read()
# ----> 7     theJSON = json.loads(data)
#       8
#       9     for element in theJSON:
#
# C:\Users\Niv\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ':' delimiter: line 10 column 18 (char 186)

# %%
import json


def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    

    

data2()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-57-590e1df592ff> in <module>()
#      35
#      36
# ---> 37 data2()
#
# <ipython-input-57-590e1df592ff> in data2()
#       9
#      10     data = open('test.json',encoding="utf8").read()
# ---> 11     theJSON = json.loads(data)
#      12
#      13     #split by year objects
#
# C:\Users\Niv\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# C:\Users\Niv\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ':' delimiter: line 10 column 18 (char 186)

# %%
import json


def data2():
    
    output = []
    
    data = open('test.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName']}] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    

    

data2()
# Out:
# [{'songs': [{'songName': 'גלגל ענק', 'year': '1980'}], 'artist': 'חלב ודבש '}, {'songs': [{'songName': 'על חטא', 'year': '1980'}], 'artist': 'צביקה פיק'}, {'songs': [{'songName': 'כל חיי', 'year': '1980'}], 'artist': 'אבי טולדנו'}, {'songs': [{'songName': 'אני שומע שוב', 'year': '1980'}, {'songName': 'לא עוזב את העיר', 'year': '1981'}], 'artist': 'שלמה ארצי'}, {'songs': [{'songName': 'שיר לשירים', 'year': '1980'}], 'artist': 'חלב ודבש'}, {'songs': [{'songName': 'לראות אותה היום', 'year': '1981'}, {'songName': 'רדיו חזק', 'year': '1981'}], 'artist': 'תיסלם'}, {'songs': [{'songName': 'סיוון', 'year': '1981'}], 'artist': 'יגאל בשן'}, {'songs': [{'songName': 'הלילה', 'year': '1981'}], 'artist': 'הכל עובר חביבי'}]
# [{'winAmount': 1, 'songs': [{'songName': 'גלגל ענק', 'year': '1980'}], 'artist': 'חלב ודבש '}, {'winAmount': 1, 'songs': [{'songName': 'על חטא', 'year': '1980'}], 'artist': 'צביקה פיק'}, {'winAmount': 1, 'songs': [{'songName': 'כל חיי', 'year': '1980'}], 'artist': 'אבי טולדנו'}, {'winAmount': 2, 'songs': [{'songName': 'אני שומע שוב', 'year': '1980'}, {'songName': 'לא עוזב את העיר', 'year': '1981'}], 'artist': 'שלמה ארצי'}, {'winAmount': 1, 'songs': [{'songName': 'שיר לשירים', 'year': '1980'}], 'artist': 'חלב ודבש'}, {'winAmount': 2, 'songs': [{'songName': 'לראות אותה היום', 'year': '1981'}, {'songName': 'רדיו חזק', 'year': '1981'}], 'artist': 'תיסלם'}, {'winAmount': 1, 'songs': [{'songName': 'סיוון', 'year': '1981'}], 'artist': 'יגאל בשן'}, {'winAmount': 1, 'songs': [{'songName': 'הלילה', 'year': '1981'}], 'artist': 'הכל עובר חביבי'}]

# %%
import json



def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] ,"artist" : song['artist'] }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"artist" : song['artist']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
data1()
data2()
# Out:
# [{'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש ', 'category': 'רוק'}, {'position': '2', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': 'רוק'}], 'year': '1980'}, {'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '2', 'gender': 'מעורב', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'הלילה', 'artist': 'הכל עובר חביבי', 'category': 'פופ'}], 'year': '1981'}]
# [{'songs': [{'songName': 'גלגל ענק', 'year': '1980', 'artist': 'חלב ודבש '}], 'artist': 'חלב ודבש '}, {'songs': [{'songName': 'על חטא', 'year': '1980', 'artist': 'צביקה פיק'}], 'artist': 'צביקה פיק'}, {'songs': [{'songName': 'כל חיי', 'year': '1980', 'artist': 'אבי טולדנו'}], 'artist': 'אבי טולדנו'}, {'songs': [{'songName': 'אני שומע שוב', 'year': '1980', 'artist': 'שלמה ארצי'}, {'songName': 'לא עוזב את העיר', 'year': '1981', 'artist': 'שלמה ארצי'}], 'artist': 'שלמה ארצי'}, {'songs': [{'songName': 'שיר לשירים', 'year': '1980', 'artist': 'חלב ודבש'}], 'artist': 'חלב ודבש'}, {'songs': [{'songName': 'לראות אותה היום', 'year': '1981', 'artist': 'תיסלם'}, {'songName': 'רדיו חזק', 'year': '1981', 'artist': 'תיסלם'}], 'artist': 'תיסלם'}, {'songs': [{'songName': 'סיוון', 'year': '1981', 'artist': 'יגאל בשן'}], 'artist': 'יגאל בשן'}, {'songs': [{'songName': 'הלילה', 'year': '1981', 'artist': 'הכל עובר חביבי'}], 'artist': 'הכל עובר חביבי'}]
# [{'winAmount': 1, 'songs': [{'songName': 'גלגל ענק', 'year': '1980', 'artist': 'חלב ודבש '}], 'artist': 'חלב ודבש '}, {'winAmount': 1, 'songs': [{'songName': 'על חטא', 'year': '1980', 'artist': 'צביקה פיק'}], 'artist': 'צביקה פיק'}, {'winAmount': 1, 'songs': [{'songName': 'כל חיי', 'year': '1980', 'artist': 'אבי טולדנו'}], 'artist': 'אבי טולדנו'}, {'winAmount': 2, 'songs': [{'songName': 'אני שומע שוב', 'year': '1980', 'artist': 'שלמה ארצי'}, {'songName': 'לא עוזב את העיר', 'year': '1981', 'artist': 'שלמה ארצי'}], 'artist': 'שלמה ארצי'}, {'winAmount': 1, 'songs': [{'songName': 'שיר לשירים', 'year': '1980', 'artist': 'חלב ודבש'}], 'artist': 'חלב ודבש'}, {'winAmount': 2, 'songs': [{'songName': 'לראות אותה היום', 'year': '1981', 'artist': 'תיסלם'}, {'songName': 'רדיו חזק', 'year': '1981', 'artist': 'תיסלם'}], 'artist': 'תיסלם'}, {'winAmount': 1, 'songs': [{'songName': 'סיוון', 'year': '1981', 'artist': 'יגאל בשן'}], 'artist': 'יגאל בשן'}, {'winAmount': 1, 'songs': [{'songName': 'הלילה', 'year': '1981', 'artist': 'הכל עובר חביבי'}], 'artist': 'הכל עובר חביבי'}]

# %%
import json



def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] ,"artist" : song['artist'] }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"artist" : song['artist']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
data1()
data2()
# Out:
# [{'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש ', 'category': 'רוק'}, {'position': '2', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': 'רוק'}], 'year': '1980'}, {'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '2', 'gender': 'מעורב', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'הלילה', 'artist': 'הכל עובר חביבי', 'category': 'פופ'}], 'year': '1981'}]
# [{'songs': [{'songName': 'גלגל ענק', 'year': '1980', 'artist': 'חלב ודבש '}], 'artist': 'חלב ודבש '}, {'songs': [{'songName': 'על חטא', 'year': '1980', 'artist': 'צביקה פיק'}], 'artist': 'צביקה פיק'}, {'songs': [{'songName': 'כל חיי', 'year': '1980', 'artist': 'אבי טולדנו'}], 'artist': 'אבי טולדנו'}, {'songs': [{'songName': 'אני שומע שוב', 'year': '1980', 'artist': 'שלמה ארצי'}, {'songName': 'לא עוזב את העיר', 'year': '1981', 'artist': 'שלמה ארצי'}], 'artist': 'שלמה ארצי'}, {'songs': [{'songName': 'שיר לשירים', 'year': '1980', 'artist': 'חלב ודבש'}], 'artist': 'חלב ודבש'}, {'songs': [{'songName': 'לראות אותה היום', 'year': '1981', 'artist': 'תיסלם'}, {'songName': 'רדיו חזק', 'year': '1981', 'artist': 'תיסלם'}], 'artist': 'תיסלם'}, {'songs': [{'songName': 'סיוון', 'year': '1981', 'artist': 'יגאל בשן'}], 'artist': 'יגאל בשן'}, {'songs': [{'songName': 'הלילה', 'year': '1981', 'artist': 'הכל עובר חביבי'}], 'artist': 'הכל עובר חביבי'}]
# [{'winAmount': 1, 'songs': [{'songName': 'גלגל ענק', 'year': '1980', 'artist': 'חלב ודבש '}], 'artist': 'חלב ודבש '}, {'winAmount': 1, 'songs': [{'songName': 'על חטא', 'year': '1980', 'artist': 'צביקה פיק'}], 'artist': 'צביקה פיק'}, {'winAmount': 1, 'songs': [{'songName': 'כל חיי', 'year': '1980', 'artist': 'אבי טולדנו'}], 'artist': 'אבי טולדנו'}, {'winAmount': 2, 'songs': [{'songName': 'אני שומע שוב', 'year': '1980', 'artist': 'שלמה ארצי'}, {'songName': 'לא עוזב את העיר', 'year': '1981', 'artist': 'שלמה ארצי'}], 'artist': 'שלמה ארצי'}, {'winAmount': 1, 'songs': [{'songName': 'שיר לשירים', 'year': '1980', 'artist': 'חלב ודבש'}], 'artist': 'חלב ודבש'}, {'winAmount': 2, 'songs': [{'songName': 'לראות אותה היום', 'year': '1981', 'artist': 'תיסלם'}, {'songName': 'רדיו חזק', 'year': '1981', 'artist': 'תיסלם'}], 'artist': 'תיסלם'}, {'winAmount': 1, 'songs': [{'songName': 'סיוון', 'year': '1981', 'artist': 'יגאל בשן'}], 'artist': 'יגאל בשן'}, {'winAmount': 1, 'songs': [{'songName': 'הלילה', 'year': '1981', 'artist': 'הכל עובר חביבי'}], 'artist': 'הכל עובר חביבי'}]

# %%
import json



def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
data1()
data2()
# Out:
# [{'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש', 'category': 'רוק'}, {'position': '2', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': 'רוק'}], 'year': '1980'}, {'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '2', 'gender': 'מעורב', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'הלילה', 'artist': 'הכל עובר חביבי', 'category': 'פופ'}], 'year': '1981'}]
# [{'songs': [{'songName': 'גלגל ענק', 'year': '1980', 'artist': 'חלב ודבש'}, {'songName': 'שיר לשירים', 'year': '1980', 'artist': 'חלב ודבש'}], 'artist': 'חלב ודבש'}, {'songs': [{'songName': 'על חטא', 'year': '1980', 'artist': 'צביקה פיק'}], 'artist': 'צביקה פיק'}, {'songs': [{'songName': 'כל חיי', 'year': '1980', 'artist': 'אבי טולדנו'}], 'artist': 'אבי טולדנו'}, {'songs': [{'songName': 'אני שומע שוב', 'year': '1980', 'artist': 'שלמה ארצי'}, {'songName': 'לא עוזב את העיר', 'year': '1981', 'artist': 'שלמה ארצי'}], 'artist': 'שלמה ארצי'}, {'songs': [{'songName': 'לראות אותה היום', 'year': '1981', 'artist': 'תיסלם'}, {'songName': 'רדיו חזק', 'year': '1981', 'artist': 'תיסלם'}], 'artist': 'תיסלם'}, {'songs': [{'songName': 'סיוון', 'year': '1981', 'artist': 'יגאל בשן'}], 'artist': 'יגאל בשן'}, {'songs': [{'songName': 'הלילה', 'year': '1981', 'artist': 'הכל עובר חביבי'}], 'artist': 'הכל עובר חביבי'}]
# [{'winAmount': 2, 'songs': [{'songName': 'גלגל ענק', 'year': '1980', 'artist': 'חלב ודבש'}, {'songName': 'שיר לשירים', 'year': '1980', 'artist': 'חלב ודבש'}], 'artist': 'חלב ודבש'}, {'winAmount': 1, 'songs': [{'songName': 'על חטא', 'year': '1980', 'artist': 'צביקה פיק'}], 'artist': 'צביקה פיק'}, {'winAmount': 1, 'songs': [{'songName': 'כל חיי', 'year': '1980', 'artist': 'אבי טולדנו'}], 'artist': 'אבי טולדנו'}, {'winAmount': 2, 'songs': [{'songName': 'אני שומע שוב', 'year': '1980', 'artist': 'שלמה ארצי'}, {'songName': 'לא עוזב את העיר', 'year': '1981', 'artist': 'שלמה ארצי'}], 'artist': 'שלמה ארצי'}, {'winAmount': 2, 'songs': [{'songName': 'לראות אותה היום', 'year': '1981', 'artist': 'תיסלם'}, {'songName': 'רדיו חזק', 'year': '1981', 'artist': 'תיסלם'}], 'artist': 'תיסלם'}, {'winAmount': 1, 'songs': [{'songName': 'סיוון', 'year': '1981', 'artist': 'יגאל בשן'}], 'artist': 'יגאל בשן'}, {'winAmount': 1, 'songs': [{'songName': 'הלילה', 'year': '1981', 'artist': 'הכל עובר חביבי'}], 'artist': 'הכל עובר חביבי'}]

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    passage = theJSON.read()

    words = re.findall(r'\w+', passage)

    cap_words = [word.upper() for word in words]

    word_counts = Counter(cap_words)
    
    print(word_counts)
    
#data1()
#data2()
data3()
# Out:
# [{'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש', 'category': 'רוק'}, {'position': '2', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': 'רוק'}], 'year': '1980'}, {'songs': [{'position': '1', 'gender': 'מעורב', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '2', 'gender': 'מעורב', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': 'רוק'}, {'position': '3', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': 'רוק'}, {'position': '4', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': 'רוק'}, {'position': '5', 'gender': 'מעורב', 'songName': 'הלילה', 'artist': 'הכל עובר חביבי', 'category': 'פופ'}], 'year': '1981'}]
# [{'songs': [{'songName': 'גלגל ענק', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823', 'year': '1980'}, {'songName': 'שיר לשירים', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351', 'year': '1980'}], 'artist': 'חלב ודבש'}, {'songs': [{'songName': 'על חטא', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=843&wrkid=9458', 'year': '1980'}], 'artist': 'צביקה פיק'}, {'songs': [{'songName': 'כל חיי', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249', 'year': '1980'}], 'artist': 'אבי טולדנו'}, {'songs': [{'songName': 'אני שומע שוב', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994', 'year': '1980'}, {'songName': 'לא עוזב את העיר', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835', 'year': '1981'}], 'artist': 'שלמה ארצי'}, {'songs': [{'songName': 'לראות אותה היום', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015', 'year': '1981'}, {'songName': 'רדיו חזק', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802', 'year': '1981'}], 'artist': 'תיסלם'}, {'songs': [{'songName': 'סיוון', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386', 'year': '1981'}], 'artist': 'יגאל בשן'}, {'songs': [{'songName': 'הלילה', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139', 'year': '1981'}], 'artist': 'הכל עובר חביבי'}]
# [{'winAmount': 2, 'songs': [{'songName': 'גלגל ענק', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=823', 'year': '1980'}, {'songName': 'שיר לשירים', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351', 'year': '1980'}], 'artist': 'חלב ודבש'}, {'winAmount': 1, 'songs': [{'songName': 'על חטא', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=843&wrkid=9458', 'year': '1980'}], 'artist': 'צביקה פיק'}, {'winAmount': 1, 'songs': [{'songName': 'כל חיי', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249', 'year': '1980'}], 'artist': 'אבי טולדנו'}, {'winAmount': 2, 'songs': [{'songName': 'אני שומע שוב', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994', 'year': '1980'}, {'songName': 'לא עוזב את העיר', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835', 'year': '1981'}], 'artist': 'שלמה ארצי'}, {'winAmount': 2, 'songs': [{'songName': 'לראות אותה היום', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015', 'year': '1981'}, {'songName': 'רדיו חזק', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802', 'year': '1981'}], 'artist': 'תיסלם'}, {'winAmount': 1, 'songs': [{'songName': 'סיוון', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386', 'year': '1981'}], 'artist': 'יגאל בשן'}, {'winAmount': 1, 'songs': [{'songName': 'הלילה', 'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139', 'year': '1981'}], 'artist': 'הכל עובר חביבי'}]

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    passage = theJSON.read()

    words = re.findall(r'\w+', passage)

    cap_words = [word.upper() for word in words]

    word_counts = Counter(cap_words)
    
    print(word_counts)
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-1bc694e2befd> in <module>()
#      71 #data1()
#      72 #data2()
# ---> 73 data3()
#
# NameError: name 'data3' is not defined

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    passage = theJSON.read()

    words = re.findall(r'\w+', passage)

    cap_words = [word.upper() for word in words]

    word_counts = Counter(cap_words)
    
    print(word_counts)
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-b6c2634e1cdb> in <module>()
#      71 #data1()
#      72 #data2()
# ---> 73 data3()
#
# <ipython-input-64-b6c2634e1cdb> in data3()
#      59     theJSON = json.loads(data)
#      60
# ---> 61     passage = theJSON.read()
#      62
#      63     words = re.findall(r'\w+', passage)
#
# AttributeError: 'dict' object has no attribute 'read'

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json') as f:
    
    passage = f.read()

    words = re.findall(r'\w+', passage)

    cap_words = [word.upper() for word in words]

    word_counts = Counter(cap_words)
    
    print(word_counts)
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-65-88157a45ff28>", line 60
#     passage = f.read()
#           ^
# IndentationError: expected an indented block

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json') as f:
    
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-66-5a001cb30eed>", line 61
#     passage = f.read()
#           ^
# IndentationError: expected an indented block

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json',encoding="utf8") as f:
    
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-67-53cf4765402b> in <module>()
#      71 #data1()
#      72 #data2()
# ---> 73 data3()
#
# <ipython-input-67-53cf4765402b> in data3()
#      59     with open('lyrics.json') as f:
#      60
# ---> 61         passage = f.read()
#      62
#      63         words = re.findall(r'\w+', passage)
#
# C:\Users\Niv\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 37: character maps to <undefined>

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json',encoding="utf8") as f:
    
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'הדרך': 3, 'ודאי': 2, 'מאלה': 2, 'ים': 2, 'יבוא': 2, 'איש': 2, 'לא': 2, 'אחרת': 2, 'של': 2, 'אל': 2, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'המלח': 1, 'סער': 1, 'בהר': 1, 'LYRICS': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'פתוח': 1, 'נצליח': 1, 'השלף': 1, 'נסער': 1, 'התמיד': 1, 'המיצרים': 1, 'מימיו': 1, 'ירוק': 1, 'לבבו': 1, 'ברקיע': 1, 'נבער': 1, 'נושיט': 1, 'יעמיקו': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'מדבר': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'כמו': 1, 'פי': 1, 'ננוח': 1, 'בוא': 1, 'בימים': 1, 'לטוב': 1, 'הרוח': 1, 'ולא': 1, 'ביד': 1, 'שורשינו': 1})

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json',encoding="utf8") as f:
    
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'הדרך': 3, 'ודאי': 2, 'מאלה': 2, 'ים': 2, 'יבוא': 2, 'איש': 2, 'לא': 2, 'אחרת': 2, 'של': 2, 'אל': 2, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'המלח': 1, 'סער': 1, 'בהר': 1, 'LYRICS': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'פתוח': 1, 'נצליח': 1, 'השלף': 1, 'נסער': 1, 'התמיד': 1, 'המיצרים': 1, 'מימיו': 1, 'ירוק': 1, 'לבבו': 1, 'ברקיע': 1, 'נבער': 1, 'נושיט': 1, 'יעמיקו': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'מדבר': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'כמו': 1, 'פי': 1, 'ננוח': 1, 'בוא': 1, 'בימים': 1, 'לטוב': 1, 'הרוח': 1, 'ולא': 1, 'ביד': 1, 'שורשינו': 1})
# 0

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json',encoding="utf8") as f:
    
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
data1()
#data2()
#data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'הדרך': 3, 'ודאי': 2, 'מאלה': 2, 'ים': 2, 'יבוא': 2, 'איש': 2, 'לא': 2, 'אחרת': 2, 'של': 2, 'אל': 2, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'המלח': 1, 'סער': 1, 'בהר': 1, 'LYRICS': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'פתוח': 1, 'נצליח': 1, 'השלף': 1, 'נסער': 1, 'התמיד': 1, 'המיצרים': 1, 'מימיו': 1, 'ירוק': 1, 'לבבו': 1, 'ברקיע': 1, 'נבער': 1, 'נושיט': 1, 'יעמיקו': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'מדבר': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'כמו': 1, 'פי': 1, 'ננוח': 1, 'בוא': 1, 'בימים': 1, 'לטוב': 1, 'הרוח': 1, 'ולא': 1, 'ביד': 1, 'שורשינו': 1})
# 0

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json',encoding="utf8") as f:
    
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# [{'songs': [{'position': '1', 'gender': 'להקה', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש', 'category': ['פופ']}, {'position': '2', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': ['פופ', 'רוק']}, {'position': '3', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': ['עברי']}, {'position': '4', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': ['עברי', 'פופ', 'רוק']}, {'position': '5', 'gender': 'להקה', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': ['פופ']}], 'year': '1980'}, {'songs': [{'position': '1', 'gender': 'להקה', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': ['פופ', 'רוק ישראלי']}, {'position': '2', 'gender': 'להקה', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': ['פופ', 'רוק ישראלי']}, {'position': '3', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': ['עברי', 'פופ', 'רוק']}, {'position': '4', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': ['עברי']}, {'position': '5', 'gender': 'להקה', 'songName': 'הלילה', 'artist': 'הכל עובר חביבי', 'category': ['פופ']}], 'year': '1981'}]

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    with open('lyrics.json',encoding="utf8") as f:
        
        theJSON = json.loads(f)
        print(theJSON)
        
        passage = f.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'הדרך': 3, 'ודאי': 2, 'מאלה': 2, 'ים': 2, 'יבוא': 2, 'איש': 2, 'לא': 2, 'אחרת': 2, 'של': 2, 'אל': 2, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'המלח': 1, 'סער': 1, 'בהר': 1, 'LYRICS': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'פתוח': 1, 'נצליח': 1, 'השלף': 1, 'נסער': 1, 'התמיד': 1, 'המיצרים': 1, 'מימיו': 1, 'ירוק': 1, 'לבבו': 1, 'ברקיע': 1, 'נבער': 1, 'נושיט': 1, 'יעמיקו': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'מדבר': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'כמו': 1, 'פי': 1, 'ננוח': 1, 'בוא': 1, 'בימים': 1, 'לטוב': 1, 'הרוח': 1, 'ולא': 1, 'ביד': 1, 'שורשינו': 1})
# 0

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
        theJSON = json.loads(data)    
        print(theJSON)
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-974677c1f449> in <module>()
#      76 #data1()
#      77 #data2()
# ---> 78 data3()
#
# <ipython-input-73-974677c1f449> in data3()
#      59     with open('lyrics.json',encoding="utf8") as f:
#      60
# ---> 61         theJSON = json.loads(f)
#      62         print(theJSON)
#      63
#
# C:\Users\Niv\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     310     if not isinstance(s, str):
#     311         raise TypeError('the JSON object must be str, not {!r}'.format(
# --> 312                             s.__class__.__name__))
#     313     if s.startswith(u'\ufeff'):
#     314         raise JSONDecodeError("Unexpected UTF-8 BOM (decode using utf-8-sig)",
#
# TypeError: the JSON object must be str, not 'TextIOWrapper'

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
        theJSON = json.loads(data)    
        print(theJSON[lyrics])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-74-2dc1fb02e9b0>", line 62
#     theJSON = json.loads(data)
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
            theJSON = json.loads(data)    
            print(theJSON[lyrics])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-75-464385882b60>", line 62
#     theJSON = json.loads(data)
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
            theJSON = json.loads(data)    
            print(theJSON[lyrics])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-76-639302ed3a9e>", line 62
#     theJSON = json.loads(data)
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    print(theJSON)
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-80c99f00d4d3> in <module>()
#      77 #data1()
#      78 #data2()
# ---> 79 data3()
#
# <ipython-input-77-80c99f00d4d3> in data3()
#      61     data = open('lyrics.json',encoding="utf8").read()
#      62     theJSON = json.loads(data)
# ---> 63     print(theJSON[lyrics])
#      64
#      65 # passage = f.read()
#
# NameError: name 'lyrics' is not defined

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    print(theJSON[lyrics])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# {'lyrics': 'עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך'}

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    print(theJSON[lyrics])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-80c99f00d4d3> in <module>()
#      77 #data1()
#      78 #data2()
# ---> 79 data3()
#
# <ipython-input-79-80c99f00d4d3> in data3()
#      61     data = open('lyrics.json',encoding="utf8").read()
#      62     theJSON = json.loads(data)
# ---> 63     print(theJSON[lyrics])
#      64
#      65 # passage = f.read()
#
# NameError: name 'lyrics' is not defined

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    for element in theJSON:
        print(element[lyrics])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-07118e010001> in <module>()
#      78 #data1()
#      79 #data2()
# ---> 80 data3()
#
# <ipython-input-80-07118e010001> in data3()
#      62     theJSON = json.loads(data)
#      63     for element in theJSON:
# ---> 64         print(element[lyrics])
#      65
#      66 # passage = f.read()
#
# NameError: name 'lyrics' is not defined

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    for element in theJSON:
        print(element)
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# lyrics

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    for element in theJSON:
        for object in element['lyrics']:
            print(element)
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-4a9519590fca> in <module>()
#      79 #data1()
#      80 #data2()
# ---> 81 data3()
#
# <ipython-input-82-4a9519590fca> in data3()
#      62     theJSON = json.loads(data)
#      63     for element in theJSON:
# ---> 64         for object in element['lyrics']:
#      65             print(element)
#      66
#
# TypeError: string indices must be integers

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    for element in theJSON:
         print(element)
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# lyrics

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    for element in theJSON:
         print(element['lyrics'])
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-c176d7966b32> in <module>()
#      78 #data1()
#      79 #data2()
# ---> 80 data3()
#
# <ipython-input-84-c176d7966b32> in data3()
#      62     theJSON = json.loads(data)
#      63     for element in theJSON:
# ---> 64          print(element['lyrics'])
#      65
#      66 # passage = f.read()
#
# TypeError: string indices must be integers

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    output = []
    
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
# passage = f.read()

#         words = re.findall(r'\w+', passage)

#         cap_words = [word.upper() for word in words]

#         word_counts = Counter(cap_words)

#         print(word_counts)
#         print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
    passage = lyrics.read()

        words = re.findall(r'\w+', passage)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

        words = re.findall(r'\w+', lyrics)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-87-953ab1823093>", line 67
#     words = re.findall(r'\w+', passage)
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

        words = re.findall(r'\w+', lyrics)

        cap_words = [word.upper() for word in words]

        word_counts = Counter(cap_words)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-88-51ce1b888857>", line 67
#     words = re.findall(r'\w+', lyrics)
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

#         words = re.findall(r'\w+', lyrics)

#         cap_words = [word.upper() for word in lyrics]

        lyrics= lyrics.split()
        print(lyrics)
        
        word_counts = Counter(lyrics)

        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-89-69bd8a59ef51>", line 69
#     cap_words = [word.upper() for word in lyrics]
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

#         words = re.findall(r'\w+', lyrics)

#         cap_words = [word.upper() for word in lyrics]
        
        lyrics = lyrics.split()
        print(lyrics)
        
        word_counts = Counter(lyrics)
    
        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-90-5ab223efcb76>", line 71
#     word_counts = Counter(lyrics)
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

#         words = re.findall(r'\w+', lyrics)

#         cap_words = [word.upper() for word in lyrics]
        
       
        print( lyrics.split())
        
#         word_counts = Counter(lyrics)
    
        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-91-2bf84cbb08c9>", line 71
#     lyrics = lyrics.split()
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

#         words = re.findall(r'\w+', lyrics)

#         cap_words = [word.upper() for word in lyrics]
        
       
        print( lyrics.split())
        
#         word_counts = Counter(lyrics)
    
        print(word_counts)
        print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-92-862e6e8498da>", line 72
#     print( lyrics.split())
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

#         words = re.findall(r'\w+', lyrics)

#         cap_words = [word.upper() for word in lyrics]
        
       
    print(lyrics.split())
        
    word_counts = Counter(lyrics)
    
    print(word_counts)
    print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']
# Counter({' ': 104, 'י': 50, 'א': 30, 'ו': 27, 'ד': 25, 'ר': 22, 'מ': 21, 'ל': 20, 'ב': 19, 'ם': 17, 'נ': 16, 'ע': 16, 'ח': 15, 'ש': 12, 'ה': 12, ',': 9, 'כ': 8, 'ק': 8, 'ת': 7, '.': 6, 'ן': 5, '-': 5, 'ט': 5, 'ס': 3, 'פ': 3, 'ך': 3, 'צ': 2, 'ז': 2, 'ף': 2, 'ג': 1})
# 0

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

    words = re.findall(r'\w+', lyrics.split())

    cap_words = [word.upper() for word in words]
        
        
    word_counts = Counter(cap_words)
    
    print(word_counts)
    print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-bd555993b9dd> in <module>()
#      78 #data1()
#      79 #data2()
# ---> 80 data3()
#
# <ipython-input-94-bd555993b9dd> in data3()
#      65 #     passage = lyrics.read()
#      66
# ---> 67     words = re.findall(r'\w+', lyrics.split())
#      68
#      69     cap_words = [word.upper() for word in lyrics]
#
# C:\Users\Niv\Anaconda3\lib\re.py in findall(pattern, string, flags)
#     211
#     212     Empty matches are included in the result."""
# --> 213     return _compile(pattern, flags).findall(string)
#     214
#     215 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics)
        
#     passage = lyrics.read()

    words = re.findall(r'\w+', lyrics.split())

    cap_words = [word.upper() for word in words]
        
        
    word_counts = Counter(cap_words)
    
    print(word_counts)
    print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-8adf7d32d1cd> in <module>()
#      78 #data1()
#      79 #data2()
# ---> 80 data3()
#
# <ipython-input-95-8adf7d32d1cd> in data3()
#      65 #     passage = lyrics.read()
#      66
# ---> 67     words = re.findall(r'\w+', lyrics.split())
#      68
#      69     cap_words = [word.upper() for word in words]
#
# C:\Users\Niv\Anaconda3\lib\re.py in findall(pattern, string, flags)
#     211
#     212     Empty matches are included in the result."""
# --> 213     return _compile(pattern, flags).findall(string)
#     214
#     215 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in words]
        
        
#     word_counts = Counter(cap_words)
    
#     print(word_counts)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

   cap_words = [word.upper() for word in lyrics.split()]
        
        
    word_counts = Counter(cap_words)
    
    print(word_counts)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-97-d7c449341064>", line 69
#     cap_words = [word.upper() for word in lyrics.split()]
#                                                          ^
# IndentationError: unindent does not match any outer indentation level

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

    cap_words = [word.upper() for word in lyrics]
        
        
    word_counts = Counter(cap_words)
    
    print(word_counts)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']
# Counter({' ': 104, 'י': 50, 'א': 30, 'ו': 27, 'ד': 25, 'ר': 22, 'מ': 21, 'ל': 20, 'ב': 19, 'ם': 17, 'נ': 16, 'ע': 16, 'ח': 15, 'ש': 12, 'ה': 12, ',': 9, 'כ': 8, 'ק': 8, 'ת': 7, '.': 6, 'ן': 5, '-': 5, 'ט': 5, 'ס': 3, 'פ': 3, 'ך': 3, 'צ': 2, 'ז': 2, 'ף': 2, 'ג': 1})

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    Counter(lyrics.split())
#     print(word_counts)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    
      print(Counter(lyrics.split()))
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-100-d6f151697d7a>", line 75
#     print(Counter(lyrics.split()))
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
      z = Counter(lyrics.split())
        print(z)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-101-b047ad3aceb1>", line 74
#     z = Counter(lyrics.split())
#     ^
# IndentationError: unexpected indent

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    lyrics.strip( '-',' ' )
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    z = Counter(lyrics.split())
    print(z)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']
# Counter({'יחד': 6, '-': 5, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'שעוד': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    lyrics.strip( '-',' ' )
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    z = Counter(lyrics.split())
    print(z)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-41446a558bd2> in <module>()
#      79 #data1()
#      80 #data2()
# ---> 81 data3()
#
# <ipython-input-103-41446a558bd2> in data3()
#      60
#      61     lyrics = theJSON['lyrics']
# ---> 62     lyrics.strip( '-',' ' )
#      63     print(lyrics.split())
#      64
#
# TypeError: strip() takes at most 1 argument (2 given)

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    lyrics.strip( '-' )
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    z = Counter(lyrics.split())
    print(z)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']
# Counter({'יחד': 6, '-': 5, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'שעוד': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    lyrics = lyrics.strip( '-' )
    print(lyrics.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    z = Counter(lyrics.split())
    print(z)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', '-', 'כל', 'הדרך,', 'יחד', '-', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', '-', 'כל', 'הדרך']
# Counter({'יחד': 6, '-': 5, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'שעוד': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})

# %%
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    print(newstr.split())
        
#     passage = lyrics.read()

#     words = re.findall(r'\w+', lyrics.split())

#     cap_words = [word.upper() for word in lyrics]
        
        
#     word_counts = Counter(cap_words)
    
    z = Counter(newstr.split())
    print(z)
#     print(word_counts[0])
        
    
#data1()
#data2()
data3()
# Out:
# ['עוד', 'נדע', 'ימים', 'טובים', 'מאלה', 'עוד', 'נדע', 'ימים', 'טובים', 'פי', 'אלף', 'שורשינו', 'יעמיקו', 'סלע', 'כמו', 'ארזים', 'בהר.', 'עוד', 'נדע', 'ימים', 'טובים', 'מאלה,', 'עוד', 'נמתיק', 'מימיו', 'של', 'ים', 'המלח,', 'כשדה', 'ירוק', 'אחר', 'השלף', 'כאשד', 'בלב', 'מדבר.', 'יחד', 'כל', 'הדרך,', 'יחד', 'לא', 'אחרת,', 'יד', 'ביד', 'נושיט', 'לטוב', 'שעוד', 'יבוא,', 'בוא', 'יבוא.', 'יחד', 'כל', 'הדרך,', 'יחד', 'לא', 'אחרת,', 'יחד', 'איש', 'אל', 'איש', 'יפתח', 'את', 'לבבו.', 'רק', 'אם', 'נאמין', 'בעוז', 'הרוח,', 'רק', 'אם', 'נאמין', 'ולא', 'ננוח', 'מן', 'המיצרים', 'אל', 'ים', 'פתוח', 'כמים', 'רבים', 'נסער.', 'רק', 'אם', 'נאמין', 'ודאי', 'נצליח,', 'רק', 'אם', 'נאמין', 'ודאי', 'נגיע', 'בימים', 'של', 'סער', 'ברקיע', 'כאש', 'התמיד', 'נבער.', 'יחד', 'כל', 'הדרך']
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)
    d = defaultdict(int)
    for i in z:
        d[i] += 1
    result = max(d.iteritems(), key=lambda x: x[1])
    print(result)
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-107-8c59b84c3609>", line 72
#     print result
#                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)

    most_common,num_most_common = Counter(L).most_common(1)[0]
    print(most_common)
        
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-f371ec6a792f> in <module>()
#      75 #data1()
#      76 #data2()
# ---> 77 data3()
#
# <ipython-input-108-f371ec6a792f> in data3()
#      69     for i in z:
#      70         d[i] += 1
# ---> 71     result = max(d.iteritems(), key=lambda x: x[1])
#      72     print(result)
#      73
#
# AttributeError: 'collections.defaultdict' object has no attribute 'iteritems'

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)

    most_common,num_most_common = Counter(L).most_common(1)[0]
    print(most_common)
        
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-86cb7070d1d0> in <module>()
#      73 #data1()
#      74 #data2()
# ---> 75 data3()
#
# <ipython-input-109-86cb7070d1d0> in data3()
#      67     print(z)
#      68
# ---> 69     most_common,num_most_common = Counter(L).most_common(1)[0]
#      70     print(most_common)
#      71
#
# NameError: name 'L' is not defined

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)

    most_common,num_most_common = Counter(z).most_common(1)[0]
    print(most_common)
        
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})
# יחד

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)

    most_common,num_most_common = Counter(z).most_common(1)[0]
    print(most_common)
     print(num_most_common)
        
    
#data1()
#data2()
data3()
# Out:
#   File "<ipython-input-111-bfac3c2a35c5>", line 71
#     print(num_most_common)
#     ^
# IndentationError: unexpected indent

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
         del element['lyrics']

    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3():
    
    #with open('lyrics.json',encoding="utf8") as f:
    
    data = open('lyrics.json',encoding="utf8").read()
    theJSON = json.loads(data)    
    
    lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)

    most_common,num_most_common = Counter(z).most_common(1)[0]
    print(most_common)
    print(num_most_common)
        
    
#data1()
#data2()
data3()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})
# יחד
# 6

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
#          del element['lyrics']
           word = data3(element['lyrics'])
           print(word) 
        
    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3(lyrics):
    
#     #with open('lyrics.json',encoding="utf8") as f:
    
#     data = open('lyrics.json',encoding="utf8").read()
#     theJSON = json.loads(data)    
    
#     lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)
    
    #return the the most common word
    most_common,num_most_common = Counter(z).most_common(1)[0]
    print(most_common)
    print(num_most_common)
    return most_common    
    
data1()
# data2()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})
# יחד
# 6
# יחד
# Counter({'את': 24, 'והוא': 17, 'כנחל': 8, 'הוא': 6, 'כשחל': 4, 'כליל': 4, 'כצל': 4, 'כעין': 3, 'על': 3, 'אשר': 3, 'יחידה': 3, 'כיין': 3, 'כלב': 3, 'לכל': 3, 'כגו': 3, 'לכל,': 3, 'בשרב': 2, 'למנגינת': 2, 'מכה': 2, 'ושב': 2, 'מפכה': 2, 'חטא': 2, 'יאהב': 2, 'עובר': 2, 'בוגדה': 2, 'המראה': 2, 'תוהו': 1, 'דודי': 1, 'בצרב': 1, 'חומר': 1, 'לכה': 1, 'אללה': 1, 'ודם': 1, 'לוקקה': 1, 'כבד': 1, 'בין': 1, 'פקע': 1, 'מצטמר': 1, 'דולק': 1, 'נוקב': 1, 'נרתע': 1, 'נשמת': 1, 'תצעני': 1, 'אפלה': 1, 'תלהטי': 1, 'כפר': 1, 'שותת': 1, 'הבתרים': 1, 'בבהטאבן': 1, 'שוקקה': 1, 'רחום': 1, 'תלכחי': 1, 'חטאת': 1, 'בלהב': 1, 'ברצע': 1, 'כהד': 1, 'פיק': 1, 'נר': 1, 'צביקה': 1, 'יחומה': 1, 'מתנודד': 1, 'דמום': 1, 'מוכה': 1, 'החטא': 1, 'ומרצד': 1, 'מתנגן': 1, 'כבה': 1, 'איבו': 1, 'קשה': 1, 'בלהבות': 1, 'בכל,': 1, 'צוחקה': 1, 'שכולה': 1, 'אוכלה': 1, 'מילים': 1, 'יתרים': 1, 'בוער': 1, 'כמוהו': 1, 'ערמה': 1, 'רוחפה': 1, 'מבקש': 1, 'בשר': 1, 'משתרבט': 1, 'בכדי': 1, 'נמוגה': 1, 'זועק': 1, 'מיתר': 1, 'אתנשמת': 1, 'נגר': 1, 'לשיר': 1, 'לוהטה': 1, 'אדם': 1, 'בכל': 1, 'האכזב': 1, 'כחיה': 1, 'חמוקה': 1, 'מרעיד': 1, 'עקוד': 1, 'מתוקה': 1})
# את
# 24
# את
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139
# [{'songs': [{'lyrics': 'עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך', 'position': '1', 'gender': 'להקה', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש', 'category': ['פופ']}, {'lyrics': 'והוא מכה על חטא והוא מכה על תוהו והוא מרעיד מיתר פקע איבו בכדי והוא דמום כהד ומרצד כמוהו הוא מצטמר למנגינת לכה דודי והוא בוער כלב והוא כבה כעין והוא דולק בלהב נר נשמת אדם והוא חומר כגו והוא כבד כיין הוא מתנודד למנגינת בשר ודם את יחידה כצל את בוגדה כנחל את תצעני לכל, לכל עובר ושב את מתוקה כליל את חמוקה כשחל את מפכה כנחל בשרב את יחידה כצל את בוגדה כנחל את תלהטי לכל, לכל עובר ושב את אפלה כליל את אוכלה כשחל את שוקקה כנחל בצרב והוא מוכה כלב והוא נרתע כעין עקוד הוא כחיה ברצע יתרים והוא שותת כגו והוא זועק כיין הוא משתרבט בלהבות בין הבתרים והוא קשה כלב והוא נוקב כעין הוא מבקש כפר החטא אשר חטאת והוא רחום כגו והוא נגר כיין הוא מתנגן בבהט-אבן את-נשמת את רוחפה כצל את לוקקה כנחל את תלכחי בכל, בכל אשר יאהב את ערמה כליל את יחומה כשחל את צוחקה כנחל האכזב את יחידה כצל את מפכה כנחל את לוהטה לכל, לכל אשר יאהב את אללה כליל את שכולה כשחל את נמוגה כנחל בשרב מילים לשיר על חטא - המראה - צביקה פיק המראה ', 'position': '2', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': ['פופ', 'רוק']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249', 'position': '3', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': ['עברי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994', 'position': '4', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': ['עברי', 'פופ', 'רוק']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351', 'position': '5', 'gender': 'להקה', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': ['פופ']}], 'year': '1980'}, {'songs': [{'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015', 'position': '1', 'gender': 'להקה', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': ['פופ', 'רוק ישראלי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802', 'position': '2', 'gender': 'להקה', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': ['פופ', 'רוק ישראלי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835', 'position': '3', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': ['עברי', 'פופ', 'רוק']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386', 'position': '4', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': ['עברי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139', 'position': '5', 'gender': 'להקה', 'songName': 'הלילה', 'artist': 'הכל עובר חביבי', 'category': ['פופ']}], 'year': '1981'}]

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
#          del element['lyrics']
           word = data3(element['lyrics'])
           element['mostCommomWord'] = word 
           print(word) 
        
    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
    
def data3(lyrics):
    
#     #with open('lyrics.json',encoding="utf8") as f:
    
#     data = open('lyrics.json',encoding="utf8").read()
#     theJSON = json.loads(data)    
    
#     lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)
    
    #return the the most common word
    most_common,num_most_common = Counter(z).most_common(1)[0]
    print(most_common)
    print(num_most_common)
    return most_common    
    
data1()
# data2()
# Out:
# Counter({'יחד': 6, 'עוד': 4, 'נאמין': 4, 'אם': 4, 'רק': 4, 'טובים': 3, 'כל': 3, 'נדע': 3, 'ימים': 3, 'ודאי': 2, 'ים': 2, 'איש': 2, 'לא': 2, 'של': 2, 'אל': 2, 'הדרך,': 2, 'אחרת,': 2, 'פי': 1, 'נגיע': 1, 'את': 1, 'סלע': 1, 'כאשד': 1, 'נמתיק': 1, 'יפתח': 1, 'כשדה': 1, 'בעוז': 1, 'רבים': 1, 'סער': 1, 'לבבו.': 1, 'בהר.': 1, 'המלח,': 1, 'כמים': 1, 'שעוד': 1, 'אחר': 1, 'לטוב': 1, 'פתוח': 1, 'השלף': 1, 'הרוח,': 1, 'מדבר.': 1, 'המיצרים': 1, 'מאלה': 1, 'מימיו': 1, 'ירוק': 1, 'נסער.': 1, 'ברקיע': 1, 'התמיד': 1, 'נושיט': 1, 'יעמיקו': 1, 'מאלה,': 1, 'יד': 1, 'מן': 1, 'כאש': 1, 'בלב': 1, 'ארזים': 1, 'אלף': 1, 'נבער.': 1, 'כמו': 1, 'ננוח': 1, 'בוא': 1, 'יבוא,': 1, 'בימים': 1, 'יבוא.': 1, 'ולא': 1, 'נצליח,': 1, 'ביד': 1, 'שורשינו': 1, 'הדרך': 1})
# יחד
# 6
# יחד
# Counter({'את': 24, 'והוא': 17, 'כנחל': 8, 'הוא': 6, 'כשחל': 4, 'כליל': 4, 'כצל': 4, 'כעין': 3, 'על': 3, 'אשר': 3, 'יחידה': 3, 'כיין': 3, 'כלב': 3, 'לכל': 3, 'כגו': 3, 'לכל,': 3, 'בשרב': 2, 'למנגינת': 2, 'מכה': 2, 'ושב': 2, 'מפכה': 2, 'חטא': 2, 'יאהב': 2, 'עובר': 2, 'בוגדה': 2, 'המראה': 2, 'תוהו': 1, 'דודי': 1, 'בצרב': 1, 'חומר': 1, 'לכה': 1, 'אללה': 1, 'ודם': 1, 'לוקקה': 1, 'כבד': 1, 'בין': 1, 'פקע': 1, 'מצטמר': 1, 'דולק': 1, 'נוקב': 1, 'נרתע': 1, 'נשמת': 1, 'תצעני': 1, 'אפלה': 1, 'תלהטי': 1, 'כפר': 1, 'שותת': 1, 'הבתרים': 1, 'בבהטאבן': 1, 'שוקקה': 1, 'רחום': 1, 'תלכחי': 1, 'חטאת': 1, 'בלהב': 1, 'ברצע': 1, 'כהד': 1, 'פיק': 1, 'נר': 1, 'צביקה': 1, 'יחומה': 1, 'מתנודד': 1, 'דמום': 1, 'מוכה': 1, 'החטא': 1, 'ומרצד': 1, 'מתנגן': 1, 'כבה': 1, 'איבו': 1, 'קשה': 1, 'בלהבות': 1, 'בכל,': 1, 'צוחקה': 1, 'שכולה': 1, 'אוכלה': 1, 'מילים': 1, 'יתרים': 1, 'בוער': 1, 'כמוהו': 1, 'ערמה': 1, 'רוחפה': 1, 'מבקש': 1, 'בשר': 1, 'משתרבט': 1, 'בכדי': 1, 'נמוגה': 1, 'זועק': 1, 'מיתר': 1, 'אתנשמת': 1, 'נגר': 1, 'לשיר': 1, 'לוהטה': 1, 'אדם': 1, 'בכל': 1, 'האכזב': 1, 'כחיה': 1, 'חמוקה': 1, 'מרעיד': 1, 'עקוד': 1, 'מתוקה': 1})
# את
# 24
# את
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386
# Counter({'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139': 1})
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139
# 1
# http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139
# [{'songs': [{'lyrics': 'עוד נדע ימים טובים מאלה עוד נדע ימים טובים פי אלף שורשינו יעמיקו סלע כמו ארזים בהר. עוד נדע ימים טובים מאלה, עוד נמתיק מימיו של ים המלח, כשדה ירוק אחר השלף כאשד בלב מדבר. יחד - כל הדרך, יחד - לא אחרת, יד ביד נושיט לטוב שעוד יבוא, בוא יבוא. יחד - כל הדרך, יחד - לא אחרת, יחד איש אל איש יפתח את לבבו. רק אם נאמין בעוז הרוח, רק אם נאמין ולא ננוח מן המיצרים אל ים פתוח כמים רבים נסער. רק אם נאמין ודאי נצליח, רק אם נאמין ודאי נגיע בימים של סער ברקיע כאש התמיד נבער. יחד - כל הדרך', 'position': '1', 'mostCommomWord': 'יחד', 'gender': 'להקה', 'songName': 'גלגל ענק', 'artist': 'חלב ודבש', 'category': ['פופ']}, {'lyrics': 'והוא מכה על חטא והוא מכה על תוהו והוא מרעיד מיתר פקע איבו בכדי והוא דמום כהד ומרצד כמוהו הוא מצטמר למנגינת לכה דודי והוא בוער כלב והוא כבה כעין והוא דולק בלהב נר נשמת אדם והוא חומר כגו והוא כבד כיין הוא מתנודד למנגינת בשר ודם את יחידה כצל את בוגדה כנחל את תצעני לכל, לכל עובר ושב את מתוקה כליל את חמוקה כשחל את מפכה כנחל בשרב את יחידה כצל את בוגדה כנחל את תלהטי לכל, לכל עובר ושב את אפלה כליל את אוכלה כשחל את שוקקה כנחל בצרב והוא מוכה כלב והוא נרתע כעין עקוד הוא כחיה ברצע יתרים והוא שותת כגו והוא זועק כיין הוא משתרבט בלהבות בין הבתרים והוא קשה כלב והוא נוקב כעין הוא מבקש כפר החטא אשר חטאת והוא רחום כגו והוא נגר כיין הוא מתנגן בבהט-אבן את-נשמת את רוחפה כצל את לוקקה כנחל את תלכחי בכל, בכל אשר יאהב את ערמה כליל את יחומה כשחל את צוחקה כנחל האכזב את יחידה כצל את מפכה כנחל את לוהטה לכל, לכל אשר יאהב את אללה כליל את שכולה כשחל את נמוגה כנחל בשרב מילים לשיר על חטא - המראה - צביקה פיק המראה ', 'position': '2', 'mostCommomWord': 'את', 'gender': 'זכר', 'songName': 'על חטא', 'artist': 'צביקה פיק', 'category': ['פופ', 'רוק']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249', 'position': '3', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=30&wrkid=8249', 'gender': 'זכר', 'songName': 'כל חיי', 'artist': 'אבי טולדנו', 'category': ['עברי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994', 'position': '4', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=2994', 'gender': 'זכר', 'songName': 'אני שומע שוב', 'artist': 'שלמה ארצי', 'category': ['עברי', 'פופ', 'רוק']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351', 'position': '5', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=405&wrkid=7351', 'gender': 'להקה', 'songName': 'שיר לשירים', 'artist': 'חלב ודבש', 'category': ['פופ']}], 'year': '1980'}, {'songs': [{'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015', 'position': '1', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2015', 'gender': 'להקה', 'songName': 'לראות אותה היום', 'artist': 'תיסלם', 'category': ['פופ', 'רוק ישראלי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802', 'position': '2', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=1021&wrkid=2802', 'gender': 'להקה', 'songName': 'רדיו חזק', 'artist': 'תיסלם', 'category': ['פופ', 'רוק ישראלי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835', 'position': '3', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=975&wrkid=1835', 'gender': 'זכר', 'songName': 'לא עוזב את העיר', 'artist': 'שלמה ארצי', 'category': ['עברי', 'פופ', 'רוק']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386', 'position': '4', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=450&wrkid=2386', 'gender': 'זכר', 'songName': 'סיוון', 'artist': 'יגאל בשן', 'category': ['עברי']}, {'lyrics': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139', 'position': '5', 'mostCommomWord': 'http://shironet.mako.co.il/artist?type=lyrics&lang=1&prfid=343&wrkid=1139', 'gender': 'להקה', 'songName': ...

# %%
from collections import defaultdict
import json
import re
from collections import Counter


def data1():
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)

    for element in theJSON: 
        for element in element['songs']:
#          del element['lyrics']
           word = data3(element['lyrics'])
           element['mostCommomWord'] = word 
           print(word) 
        
    print(theJSON)

    with open("data1.json","w", encoding='utf-8') as jsonfile:
            json.dump(theJSON,jsonfile,ensure_ascii=False)
            


def data2():
    
    output = []
    
    data = open('input.json',encoding="utf8").read()
    theJSON = json.loads(data)
    
    #split by year objects
    for yearObject in theJSON:
            #for each year split by song object 
            for song in yearObject['songs']:
                #if the artist not exist in output array
                if not any(song['artist'] == output[index]['artist'] for index in range(len(output))): 
                    output.append({"artist" : song['artist'] , "songs" : [{"year" : yearObject['year'] , "songName" : song['songName'] , "lyrics" : song['lyrics']  }] })
                #if the artist already exist in output array we add song details to array
                else:
                    index = next(index for (index, d) in enumerate(output) if d["artist"] == song['artist'])
                    output[index]['songs'].append({"year" : yearObject['year'] , "songName" : song['songName'] ,"lyrics" : song['lyrics']})
                         
               
    print(output)
    
    for object in output:
        lenght = len(object['songs'])
        object['winAmount'] = lenght 

    print(output)
    
    with open("data2.json","w", encoding='utf-8') as jsonfile:
            json.dump(output,jsonfile,ensure_ascii=False)
    
    
# find the common word in each song    
def data3(lyrics):
    
#     #with open('lyrics.json',encoding="utf8") as f:
    
#     data = open('lyrics.json',encoding="utf8").read()
#     theJSON = json.loads(data)    
    
#     lyrics = theJSON['lyrics']
    newstr = lyrics.replace("-", "")

    
    z = Counter(newstr.split())
    print(z)
    
    #return the the most common word
    most_common,num_most_common = Counter(z).most_common(1)[0]
    print(most_common)
    print(num_most_common)
    return most_common    
    
data1()
data2()
